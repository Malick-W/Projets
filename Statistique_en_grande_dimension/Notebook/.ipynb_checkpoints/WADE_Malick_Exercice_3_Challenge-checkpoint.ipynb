# %% [markdown]
# # Challenge

# %% [markdown]
# ## WADE El Hadji Malick

# %%
from time import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt    
import seaborn as sns
import math
from random import *

from collections import Counter

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import GradientBoostingClassifier, VotingClassifier
from sklearn.tree import DecisionTreeClassifier

from xgboost import XGBClassifier
import xgboost

from sklearn.metrics import auc, log_loss, recall_score, precision_score, classification_report, confusion_matrix, f1_score, matthews_corrcoef, accuracy_score, roc_auc_score,roc_curve

import sklearn.metrics

import warnings

# On ignore les avertissements des classes de modéles
warnings.filterwarnings("ignore", category=DeprecationWarning)

# On sauvegarde nos modéles finales
from sklearn.externals import joblib # save and load models

# # save the model to disk
# filename = 'modeles/SVM'
# joblib.dump(SVM, filename)

# # load the model from disk
# loaded_model = joblib.load(filename)

# %% [markdown]
# ## 1. Chargement des données

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

path_Home = "/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/data_challenge"
#path = "/users/mmath/wade/Bureau/Data/Statistique_en_grande_dimension"

Xtrainchallenge = pd.read_csv(path_Home + "/Xtrainchallenge.txt",  sep=' ')
Ytrainchallenge = pd.read_csv(path_Home + "/Ytrainchallenge.txt",  sep=' ')

Xtestchallenge = pd.read_csv(path_Home + "/Xtestchallenge.txt",  sep=' ')

# %%
print("Données Train:")
print ("Lignes: " ,Xtrainchallenge.shape[0])
print ("Colonnes: " ,Xtrainchallenge.shape[1])

print("----")

print("Données Test:")
print ("Lignes: " ,Xtestchallenge.shape[0])
print ("Colonnes: " ,Xtestchallenge.shape[1])
# Out:
# Données Train:
# Lignes:  1000
# Colonnes:  500
# ----
# Données Test:
# Lignes:  1000
# Colonnes:  500

# %%
Xtrainchallenge.head()
# Out:
#     V1   V2   V3   V4   V5   V6   V7   V8   V9  V10  V11  V12  V13  V14  V15  \
# 1  485  477  537  479  452  471  491  476  475  473  455  500  456  507  478
# 2  483  458  460  487  587  475  526  479  485  469  434  483  465  503  472
# 3  487  542  499  468  448  471  442  478  480  477  468  497  477  491  493
# 4  480  491  510  485  495  472  417  474  502  476  455  520  437  472  481
# 5  484  502  528  489  466  481  402  478  487  468  432  494  493  434  505
#
#    V16  V17  V18  V19  V20  V21  V22  V23  V24  V25  V26  V27  V28  V29  V30  \
# 1  491  447  422  480  482  515  482  464  484  477  496  509  491  459  482
# 2  478  469  518  495  491  478  530  462  494  549  469  516  487  475  486
# 3  502  465  567  510  475  474  483  490  492  544  482  454  496  491  495
# 4  436  503  522  488  468  492  488  476  479  477  485  506  476  472  506
# 5  497  486  471  467  476  455  517  483  465  512  552  505  464  472  419
#
# ...

# %%
Xtestchallenge.head()
# Out:
#        V1   V2   V3   V4   V5   V6   V7   V8   V9  V10  V11  V12  V13  V14  \
# 1001  482  538  473  485  576  479  489  477  473  479  495  527  439  485
# 1002  484  465  536  473  521  478  530  477  488  466  441  554  424  409
# 1003  487  498  501  487  503  474  427  478  496  487  533  477  464  535
# 1004  481  483  535  465  509  484  449  476  499  470  511  511  475  606
# 1005  488  501  556  478  468  481  542  477  518  469  465  518  458  526
#
#       V15  V16  V17  V18  V19  V20  V21  V22  V23  V24  V25  V26  V27  V28  \
# 1001  465  523  477  466  502  478  479  466  484  481  492  465  478  481
# 1002  481  511  463  523  450  476  469  534  479  478  542  475  498  498
# 1003  464  478  485  545  502  466  490  471  475  486  516  508  499  480
# 1004  477  520  498  482  510  475  471  498  464  476  496  484  518  478
# 1005  478  487  504  448  456  493  465  508  483  475  491  494  498  470
#
# ...

# %%
# On regroupe les données
Xchallenge = pd.concat([Xtrainchallenge,Xtestchallenge])
Xchallenge.head()
# Out:
#     V1   V2   V3   V4   V5   V6   V7   V8   V9  V10  V11  V12  V13  V14  V15  \
# 1  485  477  537  479  452  471  491  476  475  473  455  500  456  507  478
# 2  483  458  460  487  587  475  526  479  485  469  434  483  465  503  472
# 3  487  542  499  468  448  471  442  478  480  477  468  497  477  491  493
# 4  480  491  510  485  495  472  417  474  502  476  455  520  437  472  481
# 5  484  502  528  489  466  481  402  478  487  468  432  494  493  434  505
#
#    V16  V17  V18  V19  V20  V21  V22  V23  V24  V25  V26  V27  V28  V29  V30  \
# 1  491  447  422  480  482  515  482  464  484  477  496  509  491  459  482
# 2  478  469  518  495  491  478  530  462  494  549  469  516  487  475  486
# 3  502  465  567  510  475  474  483  490  492  544  482  454  496  491  495
# 4  436  503  522  488  468  492  488  476  479  477  485  506  476  472  506
# 5  497  486  471  467  476  455  517  483  465  512  552  505  464  472  419
#
# ...

# %%
print("Données Total:")
print ("Lignes: " ,Xchallenge.shape[0])
print ("Colonnes: " ,Xchallenge.shape[1])
# Out:
# Données Total:
# Lignes:  2000
# Colonnes:  500

# %%
import scipy.stats as stats
import pylab 

col1 =  choice(Xchallenge.columns) # on choisit une variable au hasard

sns.set(style="darkgrid")
sns.distplot(Xchallenge[col1])

# %%
stats.probplot(Xchallenge[col1], dist="norm", plot=pylab)
# Out:
# ((array([-3.39232293, -3.14126578, -3.00201262, ...,  3.00201262,
#           3.14126578,  3.39232293]),
#   array([452, 453, 455, ..., 512, 512, 525])),
#  (9.11861298191011, 483.3815, 0.9987802803252634))

# %%
from scipy.stats import shapiro

stat, p = shapiro(Xchallenge[col1])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('la variable semble être Gaussien (on ne rejette pas H0)')
else:
    print('La variable ne semble pas être Gaussien (On rejette H0)')
# Out:
# Statistics=0.998, p=0.008
# La variable ne semble pas être Gaussien (On rejette H0)

# %%
nombre_de_variable_gaussienne = 0

for col in list(Xchallenge.columns):
    stat, p = shapiro(Xchallenge[col])
    
    if p < 0.05:
        nombre_de_variable_gaussienne += 1
        
print("Nombre de variables non gaussiennes par le test de Shapiro: ",nombre_de_variable_gaussienne)
# Out:
# Nombre de variables non gaussiennes par le test de Shapiro:  210

# %% [markdown]
# ## 2. Feature engineering

# %% [markdown]
# #### a. VarianceThreshold

# %% [raw]
# On supprime les variables avec une faible variance

# %%
variance = 1

Col = Xchallenge.var() > variance
Col = [i for i in Col.index if Col[i]==True]

Col = list(set(Col))
Col.sort()

print("Il y'a",Xchallenge.shape[1] - len(Col),"variables avec une variance inférieure à 1")
print("Nous décidons de les écarter car elles n'apportent aucune information(variance)")
# Out:
# Il y'a 6 variables avec une variance inférieure à 1
# Nous décidons de les écarter car elles n'apportent aucune information(variance)

# %%
# on supprime les variables avec une faible variance en gardant un jeu de données initiales

Xtrainchallenge_init = Xtrainchallenge.copy()
Xtestchallenge_init = Xtestchallenge.copy()

Xtrainchallenge = Xtrainchallenge[Col] 
Xtestchallenge = Xtestchallenge[Col]

# %% [markdown]
# #### b. RFECV

# %%
from sklearn.feature_selection import RFECV

# %% [raw]
# Étant donné qu'un estimateur externe attribue des pondérations aux caractéristiques (par exemple les coefficients d'un modèle linéaire), l'objectif de l'élimination récursive des caractéristiques (RFE) est de sélectionner des caractéristiques en tenant compte de façon récursive d'ensembles toujours plus petits de caractéristiques.
#
# Premièrement, l'estimateur est formé sur l'ensemble initial de caractéristiques et l'importance de chaque caractéristique est obtenue soit par un attribut "coef_", soit par un attribut "feature_importances_". Ensuite, les caractéristiques les moins importantes sont supprimées à partir de l'ensemble des caractéristiques actuelles.
# Cette procédure est répétée récursivement sur l'ensemble taillé jusqu'à ce que le nombre souhaité de caractéristiques à sélectionner soit finalement atteint.
#
# RFE nécessite un nombre spécifié de caractéristiques à conserver, mais on ne sait souvent pas à l'avance combien de caractéristiques sont valides. Pour trouver le nombre optimal de caractéristiques, la validation croisée est utilisée avec RFE pour évaluer différents sous-ensembles de caractéristiques et sélectionner la meilleure collection de caractéristiques. Le visualiseur RFECV trace le nombre de caractéristiques du modèle ainsi que leur score de test et leur variabilité validés croisés et visualise le nombre de caractéristiques sélectionnées..

# %%
X = Xtrainchallenge
y = Ytrainchallenge

# %% [markdown]
# ##### RFECV / Séléction récursive de variables avec cross-validation et Decision Tree

# %%
# Features_opt = {}

# for i in range(100):
#     print(i+1)
    
#     MAX_DEPTH = choice(np.arange(5, 12, dtype=int))
#     CRITERION = choice(["gini", "entropy"])
    
#     rfecv = RFECV(estimator=DecisionTreeClassifier(max_depth=MAX_DEPTH, criterion=CRITERION),step=1, cv=5, scoring='accuracy', n_jobs=-1, verbose=10)
#     rfecv.fit(X, y)
#     Features_opt[i+1] = list(X.columns[rfecv.support_])

# %%
# # Example of Plot number of features VS. cross-validation scores
# plt.figure(figsize=(10,6))
# plt.xlabel("Number of features selected")
# plt.ylabel("Cross validation score (nb of correct classifications)")
# plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
# plt.show()

# %%
# Features_opt_bis = {}

# liste = []
# for col in Features_opt.values():
#     liste.extend(col)
    
# Features_opt_bis = dict(Counter(liste))
# Features_opt_bis

# # On met le résultat dans un dataFrame
# df_Features_opt = pd.DataFrame([Features_opt_bis]).rename(index={0: 'Instance'})
# df_Features_opt = df_Features_opt.sort_values(axis=1, by = 'Instance', ascending = False)

## On sauvegarde notre résultat
## df_Features_opt.to_csv(r'/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/data_challenge/df_Features_opt.csv')

# %% [markdown]
# #### c. Data Analyse

# %%
df_Features_opt = pd.read_csv("/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/data_challenge/df_Features_opt.csv",  sep=',')

# %%
print(df_Features_opt)
# Out:
#           V106  V154  V29  V379  V443  V476  V339  V454  V465  V319
# Instance    20    20   20    20    20    20    18     5     4     3

# %%
ax = df_Features_opt.T.plot(kind='bar', title ="Features's instance", figsize=(8, 4), legend=True, fontsize=12)
ax.set_xlabel(" ", fontsize=5)
ax.set_ylabel(" ", fontsize=12)
plt.show()

# %% [raw]
# les trois derniéres variables ne seront pas choisies. Alors que les 7 premiéres sont systématiquement sélectionnées.

# %%
DT_Selected_features = df_Features_opt.columns

# %% [markdown]
# ##### Pairplot

# %%
sns.set(style="ticks", color_codes=True)
Pairplot = pd.concat([X, y], axis=1)
g = sns.pairplot(Pairplot, vars=DT_Selected_features, hue="x", palette="husl")
g

# %% [raw]
# On retrouve les résultats de la premiére partie c'est-à-dire des variables qui semblent Gaussiennes mais avec une forte corrélation entre "V29" et "V319" qui est la variable la moins sélectionnée.

# %% [markdown]
# ##### Corrélation

# %%
plt.subplots(figsize=(9, 7))
sns.heatmap(X[DT_Selected_features].corr(),cmap='coolwarm', annot_kws={"size": 11}, annot=True, fmt=".2f",vmax=1, center=0, linewidths=.5)
plt.xlabel("Matrice des corrélations / Xtestchallenge")
plt.show()

# %% [raw]
# La corrélation entre "V29" et "V319" est de 0.99, les deux variables sont donc linéaires.
# On peut choisir de supprimer une des deux pour la suite, on supprime la variable "V29" car elle a une variance plus faible.

# %% [markdown]
# ##### Boxplot

# %%
fig = plt.figure(figsize=(15, 8))

plt.gcf().subplots_adjust(hspace = 0.5)
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)

ax1.set_title('Boxplot Features / Xtrainchallenge')
ax2.set_title('Boxplot Features / Xtestchallenge')

sns.boxplot(data=Xtrainchallenge[DT_Selected_features], orient="v", palette="Set2", ax=ax1)
sns.boxplot(data=Xtestchallenge[DT_Selected_features], orient="v", palette="Set2", ax=ax2)

# %% [raw]
# On supprime la variable "V454" car elle est classée avant dernier pour l'importance et elle a une variance faible.
# On constate que des outliers sont présents.

# %% [markdown]
# ##### Normalité / Test de shapiro

# %%
for col in DT_Selected_features:
    stat, p = shapiro(Xtrainchallenge[col])
    print(col,":")
    print('Statistics=%.3f, p=%.3f' % (stat, p))
    
    # interpret
    alpha = 0.05
    if p > alpha:
        print("On ne rejette pas H0: la variable",col,"semble être Gaussien")
    else:
        print("On rejette H0: la variable",col,"ne semble pas être Gaussien")
    print("")
# Out:
# V106 :
# Statistics=0.998, p=0.166
# On ne rejette pas H0: la variable V106 semble être Gaussien
#
# V154 :
# Statistics=0.973, p=0.000
# On rejette H0: la variable V154 ne semble pas être Gaussien
#
# V29 :
# Statistics=0.974, p=0.000
# On rejette H0: la variable V29 ne semble pas être Gaussien
#
# V379 :
# Statistics=0.972, p=0.000
# On rejette H0: la variable V379 ne semble pas être Gaussien
#
# V443 :
# Statistics=0.996, p=0.006
# On rejette H0: la variable V443 ne semble pas être Gaussien
#
# V476 :
# Statistics=0.970, p=0.000
# On rejette H0: la variable V476 ne semble pas être Gaussien
#
# V339 :
# Statistics=0.996, p=0.006
# On rejette H0: la variable V339 ne semble pas être Gaussien
#
# V454 :
# Statistics=0.996, p=0.009
# On rejette H0: la variable V454 ne semble pas être Gaussien
#
# V465 :
# Statistics=0.998, p=0.410
# On ne rejette pas H0: la variable V465 semble être Gaussien
#
# V319 :
# Statistics=0.973, p=0.000
# ...

# %%
Selected_features = list(DT_Selected_features)
Selected_features.remove("V29")
Selected_features.remove("V465")

print("Variables finales:",Selected_features)
# Out:
# Variables finales: ['V106', 'V154', 'V379', 'V443', 'V476', 'V339', 'V454', 'V319']

# %% [markdown]
# #### d. Premier essai avec Decision Tree

# %%
# X = Xtrainchallenge[Selected_features]
# y = Ytrainchallenge

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# #On vérifie l'équilibre des classes
# print("Total_Train:",y_train.count().x,"/ difference:",y_train.sum().x)
# print("Total_Test:",y_test.count().x,"/ difference:",y_test.sum().x)

# %% [raw]
# On a des données de Train/Test qui sont bien équilibrées!!!

# %%
# parameters = {
#     "criterion": ["gini", "entropy"],
#     "max_depth":np.arange(5, 13, dtype=int),
#     "min_samples_split": [2, 0.001, 0.005, 0.01, 0.02],
#     "min_samples_leaf": [0.001, 0.0025, 0.005, 0.01, 0.02],
#     "min_impurity_decrease" : [0.001,0.0015,0.002,0.005,0.01],
#     "max_features": [0.5, 0.75, 1., "sqrt"]
# }

# clf_DT = GridSearchCV(DecisionTreeClassifier(), parameters, scoring ="accuracy", cv=5, n_jobs=-1,verbose=8)

# clf_DT.fit(X_train, y_train)

# %%
# print("Train: ",round(clf_DT.score(X_train, y_train), 2))
# print("Test: ",round(clf_DT.score(X_test, y_test), 2))
# print("\n")
# print(clf_DT.best_params_)

# %%
# y_DT = clf_DT.predict(X_test)
# print(classification_report(y_test, y_DT))

# %%
# print(confusion_matrix(y_test, y_DT))

# %%
# y_pred = y_DT
# y_pred_proba = clf_DT.predict_proba(X_test)[:, 1]
# [fpr, tpr, thr] = roc_curve(y_test, y_pred_proba)
# # print('Train/Test split results:')
# # print("accuracy is %2.3f" % accuracy_score(y_test, y_pred))
# # print(logreg.__class__.__name__+"log_loss is %2.3f" % log_loss(y_test, y_pred_proba))
# # print(logreg.__class__.__name__+" auc is %2.3f" % auc(fpr, tpr))

# idx = np.min(np.where(tpr > 0.95)) # index of the first threshold for which the sensibility > 0.95

# plt.figure()
# plt.plot(fpr, tpr, color='coral', label='ROC curve (area = %0.3f)' % auc(fpr, tpr))
# plt.plot([0, 1], [0, 1], 'k--')
# plt.plot([0,fpr[idx]], [tpr[idx],tpr[idx]], 'k--', color='blue')
# plt.plot([fpr[idx],fpr[idx]], [0,tpr[idx]], 'k--', color='blue')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate (1 - specificity)', fontsize=14)
# plt.ylabel('True Positive Rate (recall)', fontsize=14)
# plt.title('Receiver operating characteristic (ROC) curve')
# plt.legend(loc="lower right")
# plt.show()

# print("Using a threshold of %.3f " % thr[idx] + "guarantees a sensitivity of %.3f " % tpr[idx] +  
#       "and a specificity of %.3f" % (1-fpr[idx]) + 
#       ", i.e. a false positive rate of %.2f%%." % (np.array(fpr[idx])*100))

# %% [raw]
# Les résultats sont trés bien pour un modèle simple comme Decision Tree, on peut maintenant commencer la prédiction avec des modèles plus complexes.

# %% [markdown]
# ## 3. Prédiction / XGBOOST

# %% [markdown]
# https://xgboost.readthedocs.io/en/latest/parameter.html

# %%
## XGBoost_eval_metric = {"error", "auc", "aucpr", "mlogloss"} et {"Score_Malick"}

# On peut crée soit même son métrique:
def Score_Malick(y_pred, dtrain):
    
    """ XGBoost_eval_metric ne dispose pas du métrique f1_score, on le crée (Score_Malick) """
    
    y_true = dtrain.get_label()
    err = 1-f1_score(y_true, np.round(y_pred))
    
    return 'Score_Malick', err

# %% [markdown]
# ###### Comment surveiller les performances d'entraînement avec XGBoost afin d'éviter un surajustement ?

# %% [raw]
# "early_stopping_rounds" est une approche pour former des modèles complexes d'apprentissage machine afin d'éviter le surajustement.
#
# Il fonctionne en surveillant la performance du modèle en cours de formation sur un ensemble de données de test séparé et en arrêtant la procédure de formation une fois que la performance de l'ensemble de données de test ne s'est pas améliorée après un nombre fixe d'itérations de formation.
#
# Il évite le surajustement en essayant de sélectionner automatiquement le point d'inflexion où la performance de l'ensemble de données de test commence à diminuer tandis que la performance de l'ensemble de données d'entraînement continue à s'améliorer à mesure que le modèle commence à surajuster.
#
# Le modèle XGBoost peut évaluer et rapporter les performances sur un ensemble de test pour le modèle pendant l'entraînement.
#
# Il prend en charge cette capacité en spécifiant à la fois un ensemble de données de test et une métrique d'évaluation(Score_Malick)  sur l'appel à model.fit() lors de la formation du modèle et en spécifiant la sortie verbose.
#
# Nous pouvons récupérer la performance du modèle sur l'ensemble de données d'évaluation et la tracer pour obtenir un aperçu de la façon dont l'apprentissage s'est déroulé pendant la formation.
#
# Nous fournissons un tableau de paires [(X_train, y_train), (X_test, y_test)] à l'argument "eval_metric" lorsque nous ajustons notre modèle XGBoost.Cela fournira un rapport sur la performance du modèle à la fois sur l'entraînement et sur les ensembles de tests pendant l'entraînement.

# %% [markdown]
# #### a. XGBoost avec paramétres simples

# %%
print(Selected_features)
# Out:
# ['V106', 'V154', 'V379', 'V443', 'V476', 'V339', 'V454', 'V319']

# %%
X = Xtrainchallenge[Selected_features]
y = Ytrainchallenge

XX, X_test, yy, y_test = train_test_split(X, y, test_size=0.2)

#On vérifie l'équilibre des classes
print("Total_Train-Validation:",yy.count().x,"/ difference:",yy.sum().x)
print("Total_Test:",y_test.count().x,"/ difference:",y_test.sum().x)
# Out:
# Total_Train-Validation: 800 / difference: 0
# Total_Test: 200 / difference: 2

# %%
X_train, X_val, y_train, y_val = train_test_split(XX, yy, test_size=0.16)

#On vérifie l'équilibre des classes
print("Total_Train:",y_train.count().x,"/ difference:",y_train.sum().x)
print("Total_Validation:",y_val.count().x,"/ difference:",y_val.sum().x)
# Out:
# Total_Train: 672 / difference: 0
# Total_Validation: 128 / difference: 0

# %%
print("Total_Train:",y_train.count().x,"/ difference:",y_train.sum().x)
print("Total_Validation:",y_val.count().x,"/ difference:",y_val.sum().x)
print("Total_Test:",y_test.count().x,"/ difference:",y_test.sum().x)
# Out:
# Total_Train: 672 / difference: 0
# Total_Validation: 128 / difference: 0
# Total_Test: 200 / difference: 2

# %% [raw]
# On a des données de Train/Validation/Test qui sont bien équilibrées!!!

# %%
# myXGBoost = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree = 1, eta=0.01, gamma=0, Lambda=1.0,
#               max_delta_step=0, max_features=0.5,
#               min_child_weight=1, missing=None, n_jobs=-1,
#               nthread=None, eval_metric ='error', objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=0.6, verbosity=1)

# %%
# parameters = {"n_estimators" : np.arange(5, 105, 5, dtype=int),
#               "learning_rate":  np.arange(0.001, 0.105, 0.01),
#               "max_depth":np.arange(5, 11, dtype=int),}

# clf_XGB = GridSearchCV(myXGBoost, parameters, cv=5, n_jobs=-1,verbose=5)

# eval_set = [(X_train, y_train), (X_val, y_val)]

# clf_XGB.fit(X_train, y_train, early_stopping_rounds=25, eval_metric='error', eval_set=eval_set, verbose=True)

# %% [raw]
#        ############################ SAUVEGARDE ###########################################

# %%
### On sauvegarde le modéle
# filename = '/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/Modeles/clf_XGBOOST_Version_6'
# joblib.dump(clf_XGB, filename)

# %% [raw]
#       ############################ CHARGEMENT ###########################################

# %%
# ## On charge le modéle sauvegardé
# filename = '/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/Modeles/clf_XGBOOST_Version_6'
# clf_XGB = joblib.load(filename)

# %%
# print(clf_XGB.best_params_)
# Out:
# {'learning_rate': 0.071, 'max_depth': 10, 'n_estimators': 50}

# %% [raw]
# la performance du modèle sur chaque jeu d'évaluation est stockée et rendue disponible par le modèle après la formation.
#
# "validation_0" et "validation_1" correspond à l'ordre dans lequel les ensembles de données ont été fournis à l'argument "eval_set" dans l'appel à fit().

# %%
# results= clf_XGB.best_estimator_.evals_result()
# # print(results)

# %% [raw]
# Nous pouvons ensuite utiliser ces mesures de performance recueillies pour créer un tracé de ligne et mieux comprendre comment le modèle s'est comporté sur le train et tester les ensembles de données au cours des périodes d'entraînement.

# %%
# # Récupérer les mesures de performance
# epochs = len(results['validation_0']['error'])
# x_axis = range(0, epochs)

# # plot erreur de classification Train / Test pendant la phase d'entraînement
# fig, ax = plt.subplots(figsize=(8, 4))
# ax.plot(x_axis, results['validation_0']['error'], label='Train')
# ax.plot(x_axis, results['validation_1']['error'], label='Test')
# ax.legend()
# plt.ylabel('Classification Error')
# plt.title('XGBoost Classification Error')
# plt.grid()
# plt.show()

# %% [raw]
# On peut maitenant les performances de notre modèle:

# %%
# print("Train: ",round(clf_XGB.score(X_train, y_train),2))
# print("Validation: ",round(clf_XGB.score(X_val, y_val),2))
# print("Test: ",round(clf_XGB.score(X_test, y_test),2))
# Out:
# Train:  0.95
# Validation:  0.95
# Test:  0.95

# %%
# y_myXGB = clf_XGB.predict(X_test)
# print(classification_report(y_test, y_myXGB))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.97      0.93      0.95        99
#            1       0.93      0.97      0.95       101
#
#     accuracy                           0.95       200
#    macro avg       0.95      0.95      0.95       200
# weighted avg       0.95      0.95      0.95       200

# %%
# print(confusion_matrix(y_test, y_myXGB))
# Out:
# [[92  7]
#  [ 3 98]]

# %%
# ## plot feature importance
# xgboost.plot_importance(clf_XGB.best_estimator_,max_num_features=10)
# plt.show()

# %%
y_pred = y_myXGB
y_pred_proba = clf_XGB.predict_proba(X_test)[:, 1]
[fpr, tpr, thr] = roc_curve(y_test, y_pred_proba)
# print('Train/Test split results:')
# print(logreg.__class__.__name__+" accuracy is %2.3f" % accuracy_score(y_test, y_pred))
# print(logreg.__class__.__name__+" log_loss is %2.3f" % log_loss(y_test, y_pred_proba))
# print(logreg.__class__.__name__+" auc is %2.3f" % auc(fpr, tpr))

idx = np.min(np.where(tpr > 0.95)) # index of the first threshold for which the sensibility > 0.95

plt.figure(figsize=(8, 4))
plt.plot(fpr, tpr, color='coral', label='ROC curve (area = %0.3f)' % auc(fpr, tpr))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot([0,fpr[idx]], [tpr[idx],tpr[idx]], 'k--', color='blue')
plt.plot([fpr[idx],fpr[idx]], [0,tpr[idx]], 'k--', color='blue')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1 - specificity)', fontsize=14)
plt.ylabel('True Positive Rate (recall)', fontsize=14)
plt.title('Receiver operating characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()

print("Using a threshold of %.3f " % thr[idx] + "guarantees a sensitivity of %.3f " % tpr[idx] +  
      "and a specificity of %.3f" % (1-fpr[idx]) + 
      ", i.e. a false positive rate of %.2f%%." % (np.array(fpr[idx])*100))
# Out:
# Using a threshold of 0.558 guarantees a sensitivity of 0.950 and a specificity of 0.939, i.e. a false positive rate of 6.06%.

# %% [markdown]
# ##### Conclusion:

# %%
# y_XGBoost_Version_8 = clf_XGB.predict(Xtestchallenge[Selected_features]) #données de Challenge

# path_XGBoost_Version_8 = '/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/Challenges/WADE_XGBoost_Version_8.txt'

# np.savetxt(path_XGBoost_Version_8, np.transpose(y_XGBoost_Version_8),fmt='% 0d')

# %% [raw]
# Le modéle s'est amélioré, on fait un essai Challenge avec XGBoost_Version_7 : 82.4 %
# Le modéle s'est amélioré, on fait un essai Challenge avec XGBoost_Version_8 : ??? %

# %% [raw]
#                     ##############################################################################
#                     # Il est temps pour XGBOOST de prendre des stéroïdes avec le module hyperopt #
#                     ##############################################################################

# %% [markdown]
# #### b. XGBoost tunning avec "hyperopt"

# %% [markdown]
# https://medium.com/district-data-labs/parameter-tuning-with-hyperopt-faa86acdfdce

# %% [raw]
# Il existe deux méthodes courantes de réglage des paramètres : la recherche par grille et la recherche aléatoire. Chacun a ses avantages et ses inconvénients. La recherche par grille est lente mais efficace pour chercher dans tout l'espace de recherche, tandis que la recherche aléatoire est rapide, mais pourrait manquer des points importants dans l'espace de recherche. Heureusement, une troisième option existe : l'Optimisation bayésienne. Nous allons nous concentrer sur une implémentation de l'optimisation bayésienne, un module Python appelé Hyperopt.
#
# Hyperopt est une bibliothèque python pour optimiser les espaces de recherche. Actuellement, il offre deux algorithmes d'optimisation : 1. Recherche aléatoire et 2. Tree of Parzen Estimators (TPE) qui est une approche bayésienne qui utilise P(x|y) au lieu de P(y|x), basée sur l'approximation de deux distributions différentes séparées par un seuil au lieu d'une pour calculer l'amélioration attendue (voir ceci). Auparavant, il s'adaptait aux processus gaussiens et aux arbres de régression, mais aujourd'hui, ils ne sont plus mis en œuvre.
#
# fmin() est la fonction principale d'hyperopt pour l'optimisation. Il accepte quatre arguments de base et sort le jeu de paramètres optimisé :
#
# 1. Objectif Fonction - fn
# 2. Espace de recherche - espace
# 3. Algorithme de recherche - algo
# 4. (Maximum) nombre d'évaluations - max_evals
#
#
# Le module hyperopt comprend quelques fonctions pratiques pour spécifier des plages de paramètres d'entrée.
# Au départ, il s'agit d'espaces de recherche stochastiques, mais au fur et à mesure que l'hyperopt en apprend davantage (à mesure qu'il obtient plus de rétroaction (feedback) de la fonction objectif), il adapte et échantillonne différentes parties de l'espace de recherche initial qu'il croit pouvoir lui donner la rétroaction la plus significative.
#
# * hp.choice(label, options) où les options doivent être une liste python ou tuple.
# * hp.normal(label, mu, sigma) où mu et sigma sont respectivement la moyenne et l'écart-type.
# * hp.uniform(label, low, high) où low et high sont les limites inférieure et supérieure de la plage.
# D'autres sont disponibles, tels que hp.normal, hp.lognormal, hp.quniform.
#
# Pour voir quelques dessins de l'espace de recherche, il faut importer une autre fonction, et définir l'espace de recherche.
# Exemple:

# %%
# from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
# fspace = {
#     'x': hp.uniform('x', -5, 5)
# }

# def f(params):
#     x = params['x']
#     val = x**2
#     return {'loss': val, 'status': STATUS_OK}

# trials = Trials()
# best = fmin(fn=f, space=fspace, algo=tpe.suggest, max_evals=1000, trials=trials)

# print('best:', best)
# # print('trials:')
# # for trial in trials.trials[:2]:
# #     print(trial)

# %%
# #Visualization
# f, ax = plt.subplots(1)
# xs = [t['tid'] for t in trials.trials]
# ys = [t['misc']['vals']['x'] for t in trials.trials]
# ax.set_xlim(xs[0]-10, xs[-1]+10)
# ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
# ax.set_title('$x$ $vs$ $t$ ', fontsize=18)
# ax.set_xlabel('$t$', fontsize=16)
# ax.set_ylabel('$x$', fontsize=16)

# %% [raw]
# Nous pouvons voir qu'au début, l'algorithme choisit les valeurs de l'ensemble de la plage de façon égale (uniformément), mais au fur et à mesure que le temps passe et que l'on en apprend davantage sur l'effet du paramètre sur la fonction objectif, l'algorithme se concentre de plus en plus sur les domaines dans lesquels il pense avoir le plus à gagner : la plage proche de zéro. Il explore encore tout l'espace de la solution, mais moins fréquemment.
#
# Regardons maintenant le Plot de la perte contre Val.

# %%
# f, ax = plt.subplots(1)
# xs = [t['misc']['vals']['x'] for t in trials.trials]
# ys = [t['result']['loss'] for t in trials.trials]
# ax.scatter(xs, ys, s=20, linewidth=0.01, alpha=0.75)
# ax.set_title('$val$ $vs$ $x$ ', fontsize=18)
# ax.set_xlabel('$x$', fontsize=16)
# ax.set_ylabel('$val$', fontsize=16)

# %% [raw]
# Cela nous donne ce que nous attendons, puisque la fonction y(x) = x**2 est déterministe.
# Appliquons Hyperopt à XGBOOST:

# %%
# X = Xtrainchallenge[Selected_features]
# y = Ytrainchallenge

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# #On vérifie l'équilibre des classes
# print("Total_Train:",y_train.count().x,"/ difference:",y_train.sum().x)
# print("Total_Test:",y_test.count().x,"/ difference:",y_test.sum().x)

# %%
# # les métriques de sklearn
sklearn.metrics.SCORERS.keys()

# %% [markdown]
# ##### Create the objective function

# %%
# def objective(space):
#     # Instantiate the classifier
#     clf = xgboost.XGBClassifier(n_jobs=-1, eval_metric ='error', objective='binary:logistic',booster='gbtree',
#                                 n_estimators =space['n_estimators'],
#                                 max_features =space['max_features'],
#                                 max_depth = int(space['max_depth']),
#                                 colsample_bytree=space['colsample_bytree'],
#                                 learning_rate = space['learning_rate'],
#                                 subsample = space['subsample'],
#                                 min_child_weight = space['min_child_weight'],
#                                 gamma = space['gamma'],
#                                 alpha = space['alpha'],
#                                 eta = space['eta'])
    
#     eval_set  = [(X_train, y_train), (X_test, y_test)]
    
#     # Fit the classsifier
#     clf.fit(X_train, y_train, early_stopping_rounds=25, eval_metric='error', eval_set=eval_set, verbose=False)
    
#     # Predict on Cross Validation data
#     pred = clf.predict(X_test)
    
#     # Calculate our Metric - accuracy
#     acc = accuracy_score(y_test, pred)

#     # return needs to be in this below format. We use negative of accuracy since we want to maximize it.
#     return {'loss': 1-acc, 'status': STATUS_OK }

# %% [markdown]
# ##### Create the Space for your classifier

# %%
# space = {
#     "eta" : hp.uniform("eta", 0.005, 0.2),
#     "gamma" : hp.uniform("gamma", 0.5, 1),
#     "alpha" : hp.choice("alpha", range(0, 5, 2)),
#     'min_child_weight': hp.quniform('min_child', 1, 10, 1),
#     "subsample" : hp.uniform("subsample", 0.5, 1),
#     "colsample_bytree": hp.uniform("colsample_bytree", 0.7, 1),
#     "learning_rate":  hp.uniform("learning_rate", 0.001, 0.105),
#     "max_depth": hp.choice("max_depth", range(5, 13, 1)),
#     "max_features":hp.choice("max_features", [0.5, 0.75, 1]),
#     'n_estimators' : hp.choice('n_estimators', [20,30,40,50,60,70,80,90,100, 200, 300, 400]),
#     }

# %% [markdown]
# ##### Run Hyperopt

# %%
# MAX_EVALS = 2000

# trials = Trials()
# best = fmin(fn=objective,
#             space=space,
#             algo=tpe.suggest,
#             max_evals=MAX_EVALS,
#             trials=trials)
# print('best:', best)

# %%
best

# %% [raw]
# On récupére les paramétres optimaux et on entraine nos jeux de données avec:

# %%
parameters = best # les paramétres optimaux obtenus avec Hyperopt

# %%
# XGBOOST_Version_Hyperopt = XGBClassifier(n_jobs=-1, eval_metric ='error', objective='binary:logistic',booster='gbtree',
#                           colsample_bytree = 0.77015036641328, eta = 0.09273981456453374, gamma = 0.7186111639432269,
#                           learning_rate = 0.07730506586717001, max_depth= 5, max_features = 2, min_child = 1.0,
#                           n_estimators = 11, subsample = 0.9367306962443633)

# %%
eval_set = [(X_train, y_train), (X_test, y_test)]

XGBOOST_Version_Hyperopt.fit(X_train, y_train, early_stopping_rounds=25, eval_metric='error', eval_set=eval_set, verbose=True)

# %%
# On sauvegarde le modéle
filename = '/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/Modeles/XGBOOST_Version_Hyperopt'
joblib.dump(XGBOOST_Version_Hyperopt, filename)

# # On charge le modéle sauvegardé
# filename = '/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/Modeles/XGBOOST_Version_Hyperopt'
# XGBOOST_Version_Hyperopt = joblib.load(filename)

# %%
# # Récupérer les mesures de performance
# epochs = len(results['validation_0']['error'])
# x_axis = range(0, epochs)

# # plot erreur de classification Train / Test pendant la phase d'entraînement
# fig, ax = plt.subplots(figsize=(8, 4))
# ax.plot(x_axis, results['validation_0']['error'], label='Train')
# ax.plot(x_axis, results['validation_1']['error'], label='Test')
# ax.legend()
# plt.ylabel('Classification Error')
# plt.title('XGBoost Classification Error')
# plt.grid()
# plt.show()

# %%
# print("Train: ",round(XGBOOST_Version_Hyperopt.score(X_train, y_train),2))
# print("Test: ",round(XGBOOST_Version_Hyperopt.score(X_test, y_test),2))

# %%
# y_myXGB = XGBOOST_Version_Hyperopt.predict(X_test)
# print(classification_report(y_test, y_myXGB))

# %%
# print(confusion_matrix(y_test, y_myXGB))

# %%
# ## plot feature importance
# xgboost.plot_importance(XGBOOST_Version_Hyperopt,max_num_features=10)
# plt.show()

# %%
# y_pred = y_myXGB
# y_pred_proba = XGBOOST_Version_Hyperopt.predict_proba(X_test)[:, 1]
# [fpr, tpr, thr] = roc_curve(y_test, y_pred_proba)
# # print('Train/Test split results:')
# # print(logreg.__class__.__name__+" accuracy is %2.3f" % accuracy_score(y_test, y_pred))
# # print(logreg.__class__.__name__+" log_loss is %2.3f" % log_loss(y_test, y_pred_proba))
# # print(logreg.__class__.__name__+" auc is %2.3f" % auc(fpr, tpr))

# idx = np.min(np.where(tpr > 0.95)) # index of the first threshold for which the sensibility > 0.95

# plt.figure(figsize=(8, 4))
# plt.plot(fpr, tpr, color='coral', label='ROC curve (area = %0.3f)' % auc(fpr, tpr))
# plt.plot([0, 1], [0, 1], 'k--')
# plt.plot([0,fpr[idx]], [tpr[idx],tpr[idx]], 'k--', color='blue')
# plt.plot([fpr[idx],fpr[idx]], [0,tpr[idx]], 'k--', color='blue')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate (1 - specificity)', fontsize=14)
# plt.ylabel('True Positive Rate (recall)', fontsize=14)
# plt.title('Receiver operating characteristic (ROC) curve')
# plt.legend(loc="lower right")
# plt.show()

# print("Using a threshold of %.3f " % thr[idx] + "guarantees a sensitivity of %.3f " % tpr[idx] +  
#       "and a specificity of %.3f" % (1-fpr[idx]) + 
#       ", i.e. a false positive rate of %.2f%%." % (np.array(fpr[idx])*100))

# %%
# y_XGBoost_Version_Hyperopt = XGBOOST_Version_Hyperopt.predict(Xtestchallenge[Selected_features]) #données de Challenge

# path_XGBoost_Version_Hyperopt = '/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/Challenges/WADE_XGBoost_Version__Hyperopt.txt'

# np.savetxt(path_XGBoost_Version_Hyperopt, np.transpose(y_XGBoost_Version_Hyperopt),fmt='% 0d')

# %% [markdown]
# ##### Conclusion:

# %% [raw]
# Le modéle s'est amélioré, on fait un essai Challenge avec XGBoost_Version_7 : 82.4 %
