# %% [markdown]
# # Exercice 2:  Communities and Crime

# %% [markdown]
# ## WADE El Hadji Malick

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt    
import seaborn as sns
from random import choice
from collections import Counter

import math

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, LeaveOneOut
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA

# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

from sklearn.tree import DecisionTreeRegressor
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Lasso, LassoCV, Ridge, RidgeCV
from xgboost import plot_importance
import xgboost

from sklearn.model_selection import cross_val_predict
from sys import stdout

from sklearn.metrics import median_absolute_error, mean_absolute_error,mean_squared_error, max_error, r2_score

# %% [markdown]
# ## 1. Chargement et Nettoyage des données

# %% [markdown]
# #### a. Traitement des valeurs manquantes

# %% [raw]
# On affiche les informations sur les données

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

path_Home = "/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/data_communities/"

# On affiche les informations sur les données
fichier = open(path_Home + "communities_names.txt", "r")
print(fichier.read())
fichier.close()
# Out:
# Title: Communities and Crime
#
# Abstract: Communities within the United States. The data combines socio-economic data
# from the 1990 US Census, law enforcement data from the 1990 US LEMAS survey, and crime
# data from the 1995 FBI UCR.
#
# -----------------------------------------------------------------------------------------
#
# Data Set Characteristics:  Multivariate
# Attribute Characteristics: Real
# Associated Tasks: Regression
# Number of Instances: 1994
# Number of Attributes: 128
# Missing Values? Yes
# Area: Social
# Date Donated: 2009-07-13
#
# -----------------------------------------------------------------------------------------
#
# Source:
#
# Creator: Michael Redmond (redmond 'at' lasalle.edu); Computer Science; La Salle
# University; Philadelphia, PA, 19141, USA
# -- culled from 1990 US Census, 1995 US FBI Uniform Crime Report, 1990 US Law
# Enforcement Management and Administrative Statistics Survey, available from ICPSR at U
# of Michigan.
# ...

# %%
# On récupére le nom des colonnes dans le fichier
Columns = []

with open(path_Home + "communities_columns.txt","r") as fichier:
    for ln in fichier:
        col = ln.split(" ")
        Columns.append(col[1])

# %%
df = pd.read_csv(path_Home + "communities_data.csv",  sep=';',header=None)
df.columns = Columns
df.head(10)
# Out:
#    state county community        communityname  fold  population  \
# 0      8      ?         ?         Lakewoodcity     1        0.19
# 1     53      ?         ?          Tukwilacity     1        0.00
# 2     24      ?         ?         Aberdeentown     1        0.00
# 3     34      5     81440  Willingborotownship     1        0.04
# 4     42     95      6096    Bethlehemtownship     1        0.01
# 5      6      ?         ?    SouthPasadenacity     1        0.02
# 6     44      7     41500          Lincolntown     1        0.01
# 7      6      ?         ?            Selmacity     1        0.01
# 8     21      ?         ?        Hendersoncity     1        0.03
# 9     29      ?         ?          Claytoncity     1        0.01
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  racePctHisp  \
# 0           0.33          0.02          0.90          0.12         0.17
# 1           0.16          0.12          0.74          0.45         0.07
# ...

# %%
print ("Observations: " ,df.shape[0])
print ("Variables:    " ,df.shape[1])
donnees = df.shape[0]*df.shape[1] # on mesure le nombre de données
# Out:
# Observations:  1994
# Variables:     128

# %% [raw]
# On observe des données manquantes qui sont caractérisées par un "?". On remplace ces données manquantes par des NaN qui peuvent être facilement traités par les modéles

# %%
df = df.replace("?",np.nan)

# %%
print ("\nTotal des valeurs manquantes :  ",df.isnull().sum().values.sum())

print("\n")
print(df.isnull().sum())
# Out:
# Total des valeurs manquantes :   39202
#
#
# state                       0
# county                   1174
# community                1177
# communityname               0
# fold                        0
# population                  0
# householdsize               0
# racepctblack                0
# racePctWhite                0
# racePctAsian                0
# racePctHisp                 0
# agePct12t21                 0
# agePct12t29                 0
# agePct16t24                 0
# agePct65up                  0
# numbUrban                   0
# pctUrban                    0
# medIncome                   0
# pctWWage                    0
# pctWFarmSelf                0
# pctWInvInc                  0
# pctWSocSec                  0
# pctWPubAsst                 0
# pctWRetire                  0
# medFamInc                   0
# perCapInc                   0
# whitePerCap                 0
# blackPerCap                 0
# indianPerCap                0
# ...

# %% [raw]
# On remarque qu'il y'a 24 variables avec plus de la moitié des valeurs qui sont manquantes. Il est clair que l'on fera pas de traitement de valeurs manquantes sur ces variables, une suppression "pure et simple" de ces variables sera effectuée.
# Il y'a une variable "OtherPerCap" avec une seule valeur manquante. comme on a 1994 observations, on décide de supprimer l'observation avec la valeur manquante.

# %%
# on récupére le nom des colonnes avec es valeurs manquantes sauf "OtherPerCap" qui n'en contient 1
Col_NaN = df.columns[df.isna().any()].tolist() 
Col_NaN.remove("OtherPerCap")

# %% [raw]
# On supprime toutes les colonnes avec des valeurs manquantes et la seule observation avec un valeur manquante de "OtherPerCap"

# %%
df = df.drop(Col_NaN, 1)
df = df.dropna()
print ("\nTotal des valeurs manquantes:",df.isnull().sum().values.sum())

# %% [raw]
# Toutes les valeurs manquantes ont été supprimées correctement, on a maintenant des données qui sont propres.

# %% [markdown]
# #### b. traietement des variables non prédictives

# %% [raw]
# On a  122 variables explicatives, 5 variables non explicatives et 1 variable cible à expliquée. Voici les informations qu'on a tiré de la documentation qui accompagne les données:
#
# Attribute Information: (122 predictive, 5 non-predictive, 1 goal)
# -- state: US state (by number) - not counted as predictive above, but if considered, should be consided nominal (nominal)
# -- county: numeric code for county - not predictive, and many missing values (numeric)
# -- community: numeric code for community - not predictive and many missing values (numeric)
# -- communityname: community name - not predictive - for information only (string)
# -- fold: fold number for non-random 10 fold cross validation, potentially useful for debugging, paired tests - not predictive (numeric)

# %%
# Les 5 premiéres variables sont non prédictives.
ColNonPredict = ["state", "county","community", "communityname", "fold"]

# Les variables ['county', 'community'] ont déja été supprimées avec les variables  NaN
ColNonPredict.remove('county')
ColNonPredict.remove('community')

# On supprime toutes les 3 colonnes
df = df.drop(ColNonPredict, 1)
df = df.dropna()

Perte_de_donnees = (donnees - df.shape[0]*df.shape[1])*100/donnees

print("En supprimant les valeurs manquantes et les 5 variables non prédictives, on a une perte de données de ", round(Perte_de_donnees,1),"%")
print ("\nObservations: " ,df.shape[0])
print ("variables: " ,df.shape[1])

# %% [markdown]
# #### On sauvegarde les données traitées pour R

# %% [raw]
# On sauvegarde les nouvelles pour un éventuel traitement avec le langage R.

# %%
df.to_csv(r'communities_data_R.csv')

# %% [markdown]
# ## 2. Modèles de prédiction

# %% [raw]
# On sépare les variables explicatives de la variable à expliquée.

# %%
X = df[df.columns.tolist()[:-1]] # toutes les colonnes sauf "ViolentCrimesPerPop"
y = df[df.columns.tolist()[-1]] # colonne "ViolentCrimesPerPop"

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 40)

# %% [markdown]
# #### a. DecisionTreeRegressor

# %%
#on crée un nouveau modèle gradient Boosting
DT = DecisionTreeRegressor()

#on crée un dictionnaire de toutes les valeurs que nous voulons tester
parameters = {
#     "criterion": ["gini", "entropy"],
    "max_depth":np.arange(5, 13, dtype=int),
    "max_features": [0.5,0.75,1.],
    "min_samples_split": [2, 0.001, 0.005, 0.01, 0.02],
    "min_samples_leaf": [1, 0.0025, 0.005, 0.01, 0.02],
    "min_impurity_decrease" : [0.001,0.0012,0.0015,0.0017,0.002]
}

#on utilise gridsearch pour tester toutes les valeurs de param_grid
DT_gscv = GridSearchCV(DT, parameters, cv=5, n_jobs=-1, verbose=1)

#ajustement du modèle aux données
DT_gscv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 3000 candidates, totalling 15000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    3.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-682b4d4df62c> in <module>
#      16
#      17 #ajustement du modèle aux données
# ---> 18 DT_gscv.fit(X_train,y_train)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
# ...

# %% [raw]
# La variable cible admet des valeurs proche de zéro donc la métrique MAPE ne pourra donc pas être utilisée. La seule maniére de bien mesurer notre modéle est de le comparer avec d'autre modéle ou alors de comparer son erreur avec sa moyenne et sa médiane.

# %%
mse_error_DT = mean_squared_error(y_test, DT_gscv.best_estimator_.predict(X_test))
print("MSE: %.4f" % mse_error_DT)
print("--------")
print("Moyenne: %.4f" %  y_test.mean())
print("Mediane: %.4f" %  y_test.median())
# Out:
# MSE: 0.0250
# --------
# Moyenne: 0.2510
# Mediane: 0.1600

# %%
model = DT_gscv.best_estimator_
#print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(sorted(model.feature_importances_,reverse=False), index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.figtext(.5,.9,"Importance des variables", fontsize=12, ha='center')
plt.show()

# %% [raw]
# On constate que seulement quelques variables sont importantes, ce qui était naturellement attendu vue la connaissance du sujet traité. En effet le taux de crime est souvent expliqué par des facteurs ethniques et financiers.
#
# On décide d'utiliser des modéles qui réduisent la dimensions des données. On pourrait envisager de faire une ACP mais l'un des intérêts principals de ce sujet est de dégager les facteurs c'est-à-dire les variables qui expliques le taux de crime.

# %% [markdown]
# #### b. Autres modéles avec réduction de dimensions/ PLS

# %%
# On regarde la matrice de corrélation
fig = plt.figure(1, figsize=(20, 15))

sns.heatmap(round(df.corr(),2), cmap=sns.diverging_palette(20, 220, n=200), fmt=".2f")
plt.show()

# %% [raw]
# On remarque que beaucoup de variables sont fortement corrélées entre elles. Le choix d'un modéle PLS est fortement recommandé
#
# Rappel: La régression par les moindres carrés partiels, ou encore régression PLS est une méthode rapide, efficace et optimale pour un critère de minimisation des covariances bien maîtrisé. Son utilisation est recommandée dans le cas où un grand nombre de variables explicatives est utilisé, ou lorsqu'il y a de fortes colinéarités entre les variables.

# %%
def optimise_pls_cv(X, y, n_comp, plot_components=True):
    '''Run PLS including a variable number of components, up to n_comp, and calculate MSE '''
    mse = []
    component = np.arange(1, n_comp)
    for i in component:
        pls = PLSRegression(n_components=i)
        # Cross-validation
        y_cv = cross_val_predict(pls, X, y, cv=5)
        mse.append(mean_squared_error(y, y_cv))
        comp = 100*(i+1)/100
        # Trick to update status on the same line
        stdout.write("\r%d%% completed" % comp)
        stdout.flush()
    stdout.write("\n")
    # Calculate and print the position of minimum in MSE
    msemin = np.argmin(mse)
    print("Le meilleur nombre de composants: ", msemin+1)
    stdout.write("\n")
    if plot_components is True:
        with plt.style.context(('ggplot')):
            plt.plot(component, np.array(mse), '-v', color = 'blue', mfc='blue')
            plt.plot(component[msemin], np.array(mse)[msemin], 'P', ms=10, mfc='red')
            plt.xlabel('Nombre de composants du PLS')
            plt.ylabel('MSE')
            plt.title('PLS')
            plt.xlim(left=-1)
        plt.show()
    # Define PLS object with optimal number of components
    pls_opt = PLSRegression(n_components=msemin+1)
    # Fir to the entire dataset
    pls_opt.fit(X, y)
    y_c = pls_opt.predict(X)
    # Cross-validation
    y_cv = cross_val_predict(pls_opt, X, y, cv=5)
    # Calculate scores for calibration and cross-validation
    score_c = r2_score(y, y_c)
    score_cv = r2_score(y, y_cv)
    # Calculate mean squared error for calibration and cross validation
    mse_c = mean_squared_error(y, y_c)
    mse_cv = mean_squared_error(y, y_cv)
    print('R2 calib: %5.3f'  % score_c)
    print('R2 CV: %5.3f'  % score_cv)
    print('MSE calib: %5.3f' % mse_c)
    print('MSE CV: %5.3f' % mse_cv)
    # Plot regression and figures of merit
    rangey = max(y) - min(y)
    rangex = max(y_c) - min(y_c)
    # Fit a line to the CV vs response
    z = np.polyfit(y, y_c, 1)
    return

# %%
optimise_pls_cv(X_train,y_train, 50, plot_components=True)
# Out:
# 50% completed
# Le meilleur nombre de composants:  20
# R2 calib: 0.691
# R2 CV: 0.634
# MSE calib: 0.016
# MSE CV: 0.019

# %% [raw]
# Le graphique qui apparaîtra est le MSE en fonction du nombre de composants. Le nombre suggéré de composants qui minimisent l'Erreur Quadratique Moyenne est mis en évidence sur le graphique.
# Le nombre optimal de composants est de 20, il ne reste plus qu'à mettre le modéle en pratique.

# %%
pls = PLSRegression(n_components=20)
pls.fit(X_train,y_train)
# Out:
# PLSRegression(copy=True, max_iter=500, n_components=20, scale=True, tol=1e-06)

# %%
mse_error_PLS = mean_squared_error(y_test, pls.predict(X_test))

print("MSE: %.4f" % mse_error_PLS)
print("--------")
print("Moyenne: %.4f" %  y_test.mean())
print("Mediane: %.4f" %  y_test.median())
# Out:
# MSE: 0.0182
# --------
# Moyenne: 0.2510
# Mediane: 0.1600

# %% [raw]
# Les résultats sont un peu meilleurs que le Decision Tree.

# %% [markdown]
# #### c. Lasso

# %% [raw]
# Nous effectuons une validation croisée pour choisir le meilleur alpha, réajuster le mode, calculer l'erreur de test

# %%
lassocv = LassoCV(alphas=None, cv=10, selection='random', max_iter=15000, normalize=False)
lassocv.fit(X_train, y_train)

lasso = Lasso(alpha=lassocv.alpha_, normalize=True)
lasso.fit(X_train, y_train)

mse_error_LASSO = mean_squared_error(y_test, lasso.predict(X_test))

print("MSE:",round(mse_error_LASSO,5))
print("Alpha =", lassocv.alpha_)
coef = pd.Series(lasso.coef_, index=X_train.columns)
print("Le modéle Lasso a gardé " + str(sum(coef != 0)) + " variables et a annulé les " +  str(sum(coef == 0)) + " autres variables")
# Out:
# MSE: 0.01817
# Alpha = 5.794989340557629e-05
# Le modéle Lasso a gardé 34 variables et a annulé les 66 autres variables

# %% [raw]
# On représente les variables qui ont été sélectionnées par le modéles

# %%
# plotting feature importances!
imp_coef = pd.concat([coef.sort_values().head(10),
                     coef.sort_values().tail(10)])
plt.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")
plt.show()

# %% [raw]
# On obtient presque la même erreur que le modéle PLS

# %% [markdown]
# #### d. RFECV / Séléction récursive de variables avec cross-validation et Decision Tree

# %%
# import sklearn.metrics
# sklearn.metrics.SCORERS.keys()

# %%
from sklearn.feature_selection import RFECV

# %% [raw]
# Étant donné qu'un estimateur externe attribue des pondérations aux caractéristiques (par exemple les coefficients d'un modèle linéaire), l'objectif de l'élimination récursive des caractéristiques (RFE) est de sélectionner des caractéristiques en tenant compte de façon récursive d'ensembles toujours plus petits de caractéristiques.
#
# Premièrement, l'estimateur est formé sur l'ensemble initial de caractéristiques et l'importance de chaque caractéristique est obtenue soit par un attribut "coef_", soit par un attribut "feature_importances_". Ensuite, les caractéristiques les moins importantes sont supprimées à partir de l'ensemble des caractéristiques actuelles.
# Cette procédure est répétée récursivement sur l'ensemble taillé jusqu'à ce que le nombre souhaité de caractéristiques à sélectionner soit finalement atteint.
#
# RFE nécessite un nombre spécifié de caractéristiques à conserver, mais on ne sait souvent pas à l'avance combien de caractéristiques sont valides. Pour trouver le nombre optimal de caractéristiques, la validation croisée est utilisée avec RFE pour évaluer différents sous-ensembles de caractéristiques et sélectionner la meilleure collection de caractéristiques

# %%
# Features_opt = {}

# for i in range(1000):
#     print(i+1,":")
    
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    
#     MAX_DEPTH = choice(np.arange(5, 12, dtype=int))
#     MAX_FEATURES =  choice([0.8])
    
#     rfecv = RFECV(estimator=DecisionTreeRegressor(max_depth=MAX_DEPTH, max_features=MAX_FEATURES),step=1, cv=5, scoring='neg_mean_squared_error', n_jobs=-1, verbose=1)
#     rfecv.fit(X_train, y_train)
    
#     print("score: ", round(mean_squared_error(y_test, rfecv.predict(X_test)),5))
    
#     Features_opt[i+1] = list(X_train.columns[rfecv.support_])
# Out:
# 1 :
# Fitting estimator with 100 features.
# Fitting estimator with 99 features.
# Fitting estimator with 98 features.
# Fitting estimator with 97 features.
# Fitting estimator with 96 features.
# Fitting estimator with 95 features.
# Fitting estimator with 94 features.
# Fitting estimator with 93 features.
# Fitting estimator with 92 features.
# Fitting estimator with 91 features.
# Fitting estimator with 90 features.
# Fitting estimator with 89 features.
# Fitting estimator with 88 features.
# Fitting estimator with 87 features.
# Fitting estimator with 86 features.
# Fitting estimator with 85 features.
# Fitting estimator with 84 features.
# Fitting estimator with 83 features.
# Fitting estimator with 82 features.
# Fitting estimator with 81 features.
# Fitting estimator with 80 features.
# Fitting estimator with 79 features.
# Fitting estimator with 78 features.
# Fitting estimator with 77 features.
# Fitting estimator with 76 features.
# Fitting estimator with 75 features.
# ...

# %%
# Features_opt_bis = {}

# liste = []
# for col in Features_opt.values():
#     liste.extend(col)
    
# Features_opt_bis = dict(Counter(liste))
# Features_opt_bis

# # On met le résultat dans un dataFrame
# df_Features_opt = pd.DataFrame([Features_opt_bis]).rename(index={0: 'Instance'})
# df_Features_opt = df_Features_opt.sort_values(axis=1, by = 'Instance', ascending = False)

# ## On sauvegarde notre résultat
# df_Features_opt.to_csv(r'/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/data_communities/df_Features_opt_reg.csv')

# %% [markdown]
# ##### Data Analyse

# %%
df_Features_opt = pd.read_csv(path_Home + "/df_Features_opt_reg.csv",  sep=',')

print("Instance des variables les plus importantes:")
df_Features_opt
# Out:
# Instance des variables les plus importantes:
#           PctKids2Par  PctIlleg  racePctWhite  PctPersDenseHous  HousVacant  \
# Instance          343       268           160                88          87
#
#           NumIlleg  numbUrban  FemalePctDiv  PctHousLess3BR  pctWInvInc  \
# Instance        46         43            38              37          36
#
#           PctFam2Par  TotalPctDiv  MalePctDivorce  AsianPerCap  \
# Instance          35           34              33           30
#
#           PctSpeakEnglOnly  PctLargHouseFam  HispPerCap  pctWPubAsst  \
# Instance                30               30          28           27
#
#           racePctHisp  PctPopUnderPov  PctVacantBoarded  PersPerRentOccHous  \
# Instance           23              23                22                  22
#
#           PctHousOccup  PctImmigRec8  MedYrHousBuilt  PctNotSpeakEnglWell  \
# Instance            21            20              20                   19
#
# ...

# %%
ax = df_Features_opt[df_Features_opt.columns[0:50]].T.plot(kind='bar', title ="Features's instance", figsize=(15, 4), legend=True, fontsize=12)
ax.set_xlabel(" ", fontsize=5)
ax.set_ylabel(" ", fontsize=12)
plt.show()

# %% [raw]
# On constate qu'une dizaine de variables sont souvent sélectionnées.

# %% [markdown]
# ##### Corrélation

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

path_Home = "/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/data_communities/"

# On affiche les informations sur les données
fichier = open(path_Home + "communities_names.txt", "r")
print(fichier.read())
fichier.close()
# Out:
# Title: Communities and Crime
#
# Abstract: Communities within the United States. The data combines socio-economic data
# from the 1990 US Census, law enforcement data from the 1990 US LEMAS survey, and crime
# data from the 1995 FBI UCR.
#
# -----------------------------------------------------------------------------------------
#
# Data Set Characteristics:  Multivariate
# Attribute Characteristics: Real
# Associated Tasks: Regression
# Number of Instances: 1994
# Number of Attributes: 128
# Missing Values? Yes
# Area: Social
# Date Donated: 2009-07-13
#
# -----------------------------------------------------------------------------------------
#
# Source:
#
# Creator: Michael Redmond (redmond 'at' lasalle.edu); Computer Science; La Salle
# University; Philadelphia, PA, 19141, USA
# -- culled from 1990 US Census, 1995 US FBI Uniform Crime Report, 1990 US Law
# Enforcement Management and Administrative Statistics Survey, available from ICPSR at U
# of Michigan.
# ...

# %% [raw]
# On répresente les corrélations des 20 variables les plus sélectionnées:
# -- PctIlleg: percentage of kids born to never married (numeric - decimal)

# %%
plt.subplots(figsize=(15, 12))
sns.heatmap(X[df_Features_opt.columns[0:20]].corr(),cmap='coolwarm', annot_kws={"size": 9}, annot=True, fmt=".2f",vmax=1, center=0, linewidths=3)
plt.xlabel("Matrice des corrélations / Xtrainchallenge")
plt.show()

# %% [raw]
# On selectionne les 10 premiéres variables

# %%
Selected_features = list(df_Features_opt.columns[:15])

# %% [markdown]
# #### Hyperopt/XGBOOST

# %%
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials

# %% [raw]
# Il existe deux méthodes courantes de réglage des paramètres : la recherche par grille et la recherche aléatoire. Chacun a ses avantages et ses inconvénients. La recherche par grille est lente mais efficace pour chercher dans tout l'espace de recherche, tandis que la recherche aléatoire est rapide, mais pourrait manquer des points importants dans l'espace de recherche. Heureusement, une troisième option existe : l'Optimisation bayésienne. Nous allons nous concentrer sur une implémentation de l'optimisation bayésienne, un module Python appelé Hyperopt.
#
# Hyperopt est une bibliothèque python pour optimiser les espaces de recherche. Actuellement, il offre deux algorithmes d'optimisation : la Recherche aléatoire ou le Tree of Parzen Estimators (TPE) qui est une approche bayésienne qui utilise P(x|y) au lieu de P(y|x), basée sur l'approximation de deux distributions différentes séparées par un seuil au lieu d'une pour calculer l'amélioration attendue. Auparavant, il s'adaptait aux processus gaussiens et aux arbres de régression, mais aujourd'hui, ils ne sont plus mis en œuvre.
#
# fmin() est la fonction principale d'hyperopt pour l'optimisation. Il accepte quatre arguments de base et sort le jeu de paramètres optimisé :
#
# 1. Objectif Fonction - fn
# 2. Espace de recherche - espace
# 3. Algorithme de recherche - algo
# 4. (Maximum) nombre d'évaluations - max_evals
#
#
# Le module hyperopt comprend quelques fonctions pratiques pour spécifier des plages de paramètres d'entrée.
# Au départ, il s'agit d'espaces de recherche stochastiques, mais au fur et à mesure que l'hyperopt en apprend davantage (à mesure qu'il obtient plus de rétroaction (feedback) de la fonction objectif), il adapte et échantillonne différentes parties de l'espace de recherche initial qu'il croit pouvoir lui donner la rétroaction la plus significative.
#
# * hp.uniform(label, low, high) : valeur uniforme entre low/high
# * hp.quniform(label, low, high, q) :round(uniform(.)/q)*q (notez que la valeur donne un float au lieu d'un entier)
# * hp.normal(label, mu, sigma) où mu et sigma sont respectivement la moyenne et l'écart-type.
# * hp.choice(label, options) : index d'une option (catégorielle)
# * hp.randint(label, upper) : entier aléatoire dans[0, upper)
# * hp.loguniform(label, low, high) : exp(uniform(low, high)/q)*q
# * hp.qloguniform(label, low, high, q) :round(loguniform(.)))
# * hp.normal(label, mu, sigma) : échantillonnage à partir de la distribution normale
# * hp.qnormal(label, mu, sigma, q) :rond(normal(nu, sigma)/q)*q
# * hp.lognormal(label, mu, sigma) :exp(normal(mu, sigma))
# * hp.qlognormal(label, mu, sigma, q) : round(exp(normal(.))/q)*q
#
# Pour voir quelques dessins de l'espace de recherche, il faut importer une autre fonction, et définir l'espace de recherche.

# %% [markdown]
# ##### Create the objective function

# %%
def objective(space):
    # Instantiate the classifier
    xgb = xgboost.XGBRegressor(n_jobs=-1, eval_metric='rmse', objective='reg:squarederror',
                                booster='gbtree',reg_lambda=2, min_child_weight=1,  
                                n_estimators =int(space['n_estimators']),
                                max_depth = int(space['max_depth']),
                                learning_rate = space['learning_rate'],
                                eta =space['eta'],
                                colsample_bytree = space["colsample_bytree"],
                                subsample = space["subsample"],
                                gamma = space['gamma'])

    xgb.fit(X_train[Selected_features], y=y_train)
    
    mse_error = mean_squared_error(y_test, xgb.predict(X_test[Selected_features])) 
    return {'loss': mse_error, 'status': STATUS_OK }

# %% [markdown]
# ##### Create the Space for your classifier

# %%
space = {
    "eta" : hp.uniform("eta", 0.02, 0.07),
    "gamma" : hp.uniform("gamma", 0.1, 0.99),
    "colsample_bytree" : hp.uniform("colsample_bytree", 0.5, 1.),
    "subsample" : hp.uniform("subsample", 0.5, 1.),
    "learning_rate":  hp.uniform("learning_rate", 0.005, 0.1),
    "max_depth": hp.quniform("max_depth", 4, 12, 1),
    'n_estimators' : hp.quniform('n_estimators', 5, 500, 1)}

# %% [markdown]
# ##### Run Hyperopt

# %%
MAX_EVALS = 100

trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=MAX_EVALS,
            trials=trials)
print('best:')
best # les paramétres optimaux obtenus avec Hyperopt
# Out:
# 100%|██████████| 100/100 [00:39<00:00,  1.83it/s, best loss: 0.02020651132129757]
# best:
# {'colsample_bytree': 0.5949920455946636,
#  'eta': 0.06095709952709334,
#  'gamma': 0.10106260607387947,
#  'learning_rate': 0.03117759849589458,
#  'max_depth': 7.0,
#  'n_estimators': 295.0,
#  'subsample': 0.7991155667721491}

# %% [markdown]
# ##### Validation avec X_test:

# %%
xgb = xgboost.XGBRegressor(n_jobs=-1, eval_metric='rmse', objective='reg:squarederror',
                           booster='gbtree',reg_lambda=2, min_child_weight=1,
                           n_estimators =int(best['n_estimators']),
                           max_depth = int(best['max_depth']),
                           learning_rate = best['learning_rate'],
                           eta =best['eta'],
                           colsample_bytree = best["colsample_bytree"],
                           subsample = best["subsample"],
                           gamma = best['gamma'])

xgb.fit(X_train[Selected_features], y=y_train)
    
mse_error_XGB = mean_squared_error(y_test, xgb.predict(X_test[Selected_features])) 

print("#################")
print("MSE:",round(mse_error_XGB,5))
print("#################")
# Out:
# #################
# MSE: 0.02021
# #################

# %%
## plot feature importance
xgboost.plot_importance(xgb,max_num_features=20)
plt.show()

# %% [markdown]
# ### Conclusion:

# %%
print("#################")
print("L'Erreur quadratique moyenne de DT:",round(mse_error_DT,5))
print("L'Erreur quadratique moyenne de PLS:",round(mse_error_PLS,5))
print("L'Erreur quadratique moyenne de LASSO:",round(mse_error_LASSO,5))
print("L'Erreur quadratique moyenne de XGBOOST:",round(mse_error_XGB,5))
print("#################")
# Out:
# #################
# L'Erreur quadratique moyenne de DT: 0.025
# L'Erreur quadratique moyenne de PLS: 0.01816
# L'Erreur quadratique moyenne de LASSO: 0.01817
# L'Erreur quadratique moyenne de XGBOOST: 0.02021
# #################

# %% [raw]
# Il serait beaucoup plus intéréssant de faire une Analyse de données avancée afin de bien determiner les facteurs qui expliquent réellement le taux de crime. Plusieurs facteurs ont été sélectionnés par les modéles à cause de leur corrélation entre eux.
#
# Si l'étude devait aboutir sur une action des pouvoirs publics, ils serait plus simple de dégager des facteurs explicatives sur les quels ils peuvent agir.
