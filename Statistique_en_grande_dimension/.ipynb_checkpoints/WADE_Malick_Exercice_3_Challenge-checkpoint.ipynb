# %% [markdown]
# # Communities and Crime

# %% [markdown]
# ## WADE El Hadji Malick

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt    
import seaborn as sns

import math

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier


from sklearn.externals import joblib # save and load models

# # save the model to disk
# filename = 'modeles/SVM'
# joblib.dump(SVM, filename)

# # load the model from disk
# loaded_model = joblib.load(filename)

# %% [markdown]
# ## 1. Chargement et Nettoyage des données

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

path_Home = "/home/jovyan/work/Projets/Projets/Statistique_en_grande_dimension/donnees_challenge"
#path = "/users/mmath/wade/Bureau/Data/Statistique_en_grande_dimension"

Xtrainchallenge = pd.read_csv(path_Home + "/Xtrainchallenge.txt",  sep=' ')
Ytrainchallenge = pd.read_csv(path_Home + "/Ytrainchallenge.txt",  sep=' ')

Xtestchallenge = pd.read_csv(path_Home + "/Xtestchallenge.txt",  sep=' ')

# %%
print ("Lignes: " ,Xtrainchallenge.shape[0])
print ("Colonnes: " ,Xtrainchallenge.shape[1])

print("---------------")
print ("\nVariables:")
print(Xtrainchallenge.dtypes)
# Out:
# Lignes:  1000
# Colonnes:  500
# ---------------
#
# Variables:
# V1      int64
# V2      int64
# V3      int64
# V4      int64
# V5      int64
# V6      int64
# V7      int64
# V8      int64
# V9      int64
# V10     int64
# V11     int64
# V12     int64
# V13     int64
# V14     int64
# V15     int64
# V16     int64
# V17     int64
# V18     int64
# V19     int64
# V20     int64
# V21     int64
# V22     int64
# V23     int64
# V24     int64
# V25     int64
# V26     int64
# V27     int64
# V28     int64
# V29     int64
# V30     int64
# V31     int64
# V32     int64
# V33     int64
# V34     int64
# V35     int64
# V36     int64
# V37     int64
# V38     int64
# V39     int64
# V40     int64
# V41     int64
# V42     int64
# V43     int64
# V44     int64
# V45     int64
# V46     int64
# V47     int64
# V48     int64
# V49     int64
# V50     int64
# V51     int64
# V52     int64
# V53     int64
# V54     int64
# V55     int64
# V56     int64
# V57     int64
# V58     int64
# V59     int64
# V60     int64
# V61     int64
# V62     int64
# V63     int64
# V64     int64
# V65     int64
# V66     int64
# V67     int64
# V68     int64
# V69     int64
# V70     int64
# V71     int64
# V72     int64
# V73     int64
# V74     int64
# V75     int64
# V76     int64
# V77     int64
# V78     int64
# V79     int64
# V80     int64
# V81     int64
# V82     int64
# V83     int64
# V84     int64
# V85     int64
# V86     int64
# V87     int64
# V88     int64
# V89     int64
# V90     int64
# V91     int64
# V92     int64
# V93     int64
# V94     int64
# V95     int64
# V96     int64
# V97     int64
# V98     int64
# V99     int64
# V100    int64
# V101    int64
# V102    int64
# V103    int64
# V104    int64
# V105    int64
# V106    int64
# V107    int64
# V108    int64
# V109    int64
# V110    int64
# V111    int64
# V112    int64
# V113    int64
# V114    int64
# V115    int64
# V116    int64
# V117    int64
# V118    int64
# V119    int64
# V120    int64
# V121    int64
# V122    int64
# V123    int64
# V124    int64
# V125    int64
# V126    int64
# V127    int64
# V128    int64
# V129    int64
# V130    int64
# V131    int64
# V132    int64
# V133    int64
# V134    int64
# V135    int64
# V136    int64
# V137    int64
# V138    int64
# V139    int64
# V140    int64
# V141    int64
# V142    int64
# V143    int64
# V144    int64
# V145    int64
# V146    int64
# V147    int64
# V148    int64
# V149    int64
# V150    int64
# V151    int64
# V152    int64
# V153    int64
# V154    int64
# V155    int64
# V156    int64
# V157    int64
# V158    int64
# V159    int64
# V160    int64
# V161    int64
# V162    int64
# V163    int64
# V164    int64
# V165    int64
# V166    int64
# V167    int64
# V168    int64
# V169    int64
# V170    int64
# V171    int64
# V172    int64
# V173    int64
# V174    int64
# V175    int64
# V176    int64
# V177    int64
# V178    int64
# V179    int64
# V180    int64
# V181    int64
# V182    int64
# V183    int64
# V184    int64
# V185    int64
# V186    int64
# V187    int64
# V188    int64
# V189    int64
# V190    int64
# V191    int64
# V192    int64
# V193    int64
# V194    int64
# V195    int64
# V196    int64
# V197    int64
# V198    int64
# V199    int64
# V200    int64
# V201    int64
# V202    int64
# V203    int64
# V204    int64
# V205    int64
# V206    int64
# V207    int64
# V208    int64
# V209    int64
# V210    int64
# V211    int64
# V212    int64
# V213    int64
# V214    int64
# V215    int64
# V216    int64
# V217    int64
# V218    int64
# V219    int64
# V220    int64
# V221    int64
# V222    int64
# V223    int64
# V224    int64
# V225    int64
# V226    int64
# V227    int64
# V228    int64
# V229    int64
# V230    int64
# V231    int64
# V232    int64
# V233    int64
# V234    int64
# V235    int64
# V236    int64
# V237    int64
# V238    int64
# V239    int64
# V240    int64
# V241    int64
# V242    int64
# V243    int64
# V244    int64
# V245    int64
# V246    int64
# V247    int64
# V248    int64
# V249    int64
# V250    int64
# V251    int64
# V252    int64
# V253    int64
# V254    int64
# V255    int64
# V256    int64
# V257    int64
# V258    int64
# V259    int64
# V260    int64
# V261    int64
# V262    int64
# V263    int64
# V264    int64
# V265    int64
# V266    int64
# V267    int64
# V268    int64
# V269    int64
# V270    int64
# V271    int64
# V272    int64
# V273    int64
# V274    int64
# V275    int64
# V276    int64
# V277    int64
# V278    int64
# V279    int64
# V280    int64
# V281    int64
# V282    int64
# V283    int64
# V284    int64
# V285    int64
# V286    int64
# V287    int64
# V288    int64
# V289    int64
# V290    int64
# V291    int64
# V292    int64
# V293    int64
# V294    int64
# V295    int64
# V296    int64
# V297    int64
# V298    int64
# V299    int64
# V300    int64
# V301    int64
# V302    int64
# V303    int64
# V304    int64
# V305    int64
# V306    int64
# V307    int64
# V308    int64
# V309    int64
# V310    int64
# V311    int64
# V312    int64
# V313    int64
# V314    int64
# V315    int64
# V316    int64
# V317    int64
# V318    int64
# V319    int64
# V320    int64
# V321    int64
# V322    int64
# V323    int64
# V324    int64
# V325    int64
# V326    int64
# V327    int64
# V328    int64
# V329    int64
# V330    int64
# V331    int64
# V332    int64
# V333    int64
# V334    int64
# V335    int64
# V336    int64
# V337    int64
# V338    int64
# V339    int64
# V340    int64
# V341    int64
# V342    int64
# V343    int64
# V344    int64
# V345    int64
# V346    int64
# V347    int64
# V348    int64
# V349    int64
# V350    int64
# V351    int64
# V352    int64
# V353    int64
# V354    int64
# V355    int64
# V356    int64
# V357    int64
# V358    int64
# V359    int64
# V360    int64
# V361    int64
# V362    int64
# V363    int64
# V364    int64
# V365    int64
# V366    int64
# V367    int64
# V368    int64
# V369    int64
# V370    int64
# V371    int64
# V372    int64
# V373    int64
# V374    int64
# V375    int64
# V376    int64
# V377    int64
# V378    int64
# V379    int64
# V380    int64
# V381    int64
# V382    int64
# V383    int64
# V384    int64
# V385    int64
# V386    int64
# V387    int64
# V388    int64
# V389    int64
# V390    int64
# V391    int64
# V392    int64
# V393    int64
# V394    int64
# V395    int64
# V396    int64
# V397    int64
# V398    int64
# V399    int64
# V400    int64
# V401    int64
# V402    int64
# V403    int64
# V404    int64
# V405    int64
# V406    int64
# V407    int64
# V408    int64
# V409    int64
# V410    int64
# V411    int64
# V412    int64
# V413    int64
# V414    int64
# V415    int64
# V416    int64
# V417    int64
# V418    int64
# V419    int64
# V420    int64
# V421    int64
# V422    int64
# V423    int64
# V424    int64
# V425    int64
# V426    int64
# V427    int64
# V428    int64
# V429    int64
# V430    int64
# V431    int64
# V432    int64
# V433    int64
# V434    int64
# V435    int64
# V436    int64
# V437    int64
# V438    int64
# V439    int64
# V440    int64
# V441    int64
# V442    int64
# V443    int64
# V444    int64
# V445    int64
# V446    int64
# V447    int64
# V448    int64
# V449    int64
# V450    int64
# V451    int64
# V452    int64
# V453    int64
# V454    int64
# V455    int64
# V456    int64
# V457    int64
# V458    int64
# V459    int64
# V460    int64
# V461    int64
# V462    int64
# V463    int64
# V464    int64
# V465    int64
# V466    int64
# V467    int64
# V468    int64
# V469    int64
# V470    int64
# V471    int64
# V472    int64
# V473    int64
# V474    int64
# V475    int64
# V476    int64
# V477    int64
# V478    int64
# V479    int64
# V480    int64
# V481    int64
# V482    int64
# V483    int64
# V484    int64
# V485    int64
# V486    int64
# V487    int64
# V488    int64
# V489    int64
# V490    int64
# V491    int64
# V492    int64
# V493    int64
# V494    int64
# V495    int64
# V496    int64
# V497    int64
# V498    int64
# V499    int64
# V500    int64
# dtype: object

# %%
# Col_train = Xtrainchallenge.std() > 1.5
# Col_train = [i for i in Col_train.index if Col_train[i]==True]

# Xtrainchallenge = Xtrainchallenge[Col_train]
# Xtestchallenge = Xtestchallenge[Col_train]

# X_train, X_test, y_train, y_test = train_test_split(Xtrainchallenge,Ytrainchallenge,test_size = 0.3)

# from sklearn.tree import DecisionTreeClassifier

# start = time.time()

# parameters = {
#     "criterion": ["gini", "entropy"],
#     "max_depth":[3, 5, 8, 10],
#     "min_samples_split": [2, 0.001, 0.005],
#     "min_samples_leaf": [0.001, 0.005, 0.01, 0.01, 0.05],
#     "max_features": [1., "sqrt"]
#     }

# clf_DT = GridSearchCV(DecisionTreeClassifier(), parameters, cv=5, n_jobs=-1,verbose=10)

# clf_DT.fit(X_train, y_train)

# end=time.time()
# train_time_dec=end-start

# print("Train: ",clf_DT.score(X_train, y_train))
# print("Test: ",clf_DT.score(X_test, y_test))
# print("\n")
# print(clf_DT.best_params_)

# %%
# Xtrainchallenge = Xtrainchallenge[Col_train]
# Xtestchallenge = Xtestchallenge[Col_train]

# X_train, X_test, y_train, y_test = train_test_split(Xtrainchallenge,Ytrainchallenge,test_size = 0.3)

# from sklearn.tree import DecisionTreeClassifier

# start = time.time()

# parameters = {
#     "criterion": ["gini", "entropy"],
#     "max_depth":[3, 5, 8, 10],
#     "min_samples_split": [2, 0.001, 0.005],
#     "min_samples_leaf": [0.001, 0.005, 0.01, 0.01, 0.05],
#     "max_features": [1., "sqrt"]
#     }

# clf_DT = GridSearchCV(DecisionTreeClassifier(), parameters, cv=5, n_jobs=-1,verbose=10)

# clf_DT.fit(X_train, y_train)

# end=time.time()
# train_time_dec=end-start

# print("Train: ",clf_DT.score(X_train, y_train))
# print("Test: ",clf_DT.score(X_test, y_test))
# print("\n")
# print(clf_DT.best_params_)

# %%
# # On regarde la matrice de corrélation
# fig = plt.figure(1, figsize=(50, 50))

# sns.heatmap(round(Xtrainchallenge.corr(),2), cmap=sns.diverging_palette(20, 220, n=200), fmt=".2f")
# plt.show()

# %%
# print ("Lignes: " ,Xtrainchallenge.shape[0])
# print ("Colonnes: " ,Xtrainchallenge.shape[1])

# %% [markdown]
# ## 2. Modèles de prédiction

# %%
# X_train, X_test, y_train, y_test = train_test_split(Xtrainchallenge,Ytrainchallenge,test_size = 0.3)

# from sklearn.tree import DecisionTreeClassifier

# start = time.time()

# parameters = {
#     "criterion": ["gini", "entropy"],
#     "max_depth":[3, 5, 8, 10],
#     "min_samples_split": [2, 0.001, 0.005],
#     "min_samples_leaf": [0.001, 0.005, 0.01, 0.01, 0.05],
#     "max_features": [1., "sqrt"]
#     }

# clf_DT = GridSearchCV(DecisionTreeClassifier(), parameters, cv=5, n_jobs=-1,verbose=10)

# clf_DT.fit(X_train, y_train)

# end=time.time()
# train_time_dec=end-start

# print("Train: ",clf_DT.score(X_train, y_train))
# print("Test: ",clf_DT.score(X_test, y_test))
# print("\n")
# print(clf_DT.best_params_)

# %%
# X_train = Xtrainchallenge
# X_test = Xtestchallenge
# y_train = Ytrainchallenge

# %%
# n_components = 150

# # TODO: Create an instance of PCA, initializing with n_components=n_components and whiten=True
# pca = PCA(n_components=n_components, whiten=True, svd_solver='randomized')

# #TODO: pass the training dataset (X_train) to pca's 'fit()' method
# pca = pca.fit(X_train)

# %%
# print("proportion de variance associée aux 10 premiéres axes:\n",pca.explained_variance_ratio_[:100])

# %%
# print("proportion total de variance associées aux axes: ",round(sum(pca.explained_variance_ratio_),4))

# %%
#Apply dimensionality reduction to X.
# X_train_pca = pca.transform(X_train)
# X_test_pca = pca.transform(X_test)

# %% [markdown]
# #### a. LogisticRegression

# %%
# y_pred_Logit = Logit_gscv.predict(X_test)

# %%
# np.savetxt('WADE_premier_test.txt', np.transpose(y_pred_Logit))
# y_pred_Logit = Logit_gscv.predict(X_test)

# %%
# from sklearn.tree import DecisionTreeClassifier

# start = time.time()

# parameters = {
#     "criterion": ["gini", "entropy"],
#     "max_depth":[3, 5, 8, 10],
#     "min_samples_split": [2, 0.001, 0.005],
#     "min_samples_leaf": [0.001, 0.005, 0.01, 0.01, 0.05],
#     "max_features": [1., "sqrt"]
#     }

# clf_DT = GridSearchCV(DecisionTreeClassifier(), parameters, cv=5, n_jobs=-1,verbose=10)

# clf_DT.fit(X_train, y_train)

# end=time.time()
# train_time_dec=end-start

# print("Train: ",clf_DT.score(X_train, y_train))
# print("Test: ",clf_DT.score(X_test, y_test))
# print("\n")
# print(clf_DT.best_params_)

# %%
# y_dt = clf_DT.predict(X_test)
# confusion_matrix(y_test, y_dt)

# %%
# # construire la courbe ROC
# from sklearn import metrics
# fpr, tpr, thr = metrics.roc_curve(y_test, y_dt)

# # calculer l'aire sous la courbe ROC
# auc = metrics.auc(fpr, tpr)

# # créer une figure
# from matplotlib import pyplot as plt
# fig = plt.figure(figsize=(7,7))

# # afficher la courbe ROC
# plt.plot(fpr, tpr, '-', lw=2, label='AUC=%.2f' % auc)

# # donner un titre aux axes et au graphique
# plt.xlabel('False Positive Rate', fontsize=16)
# plt.ylabel('True Positive Rate', fontsize=16)
# plt.title('Courbe ROC Décision Tree', fontsize=16)

# # afficher la légende
# plt.legend(loc="lower right", fontsize=14)

# # afficher l'image
# plt.show()

# %%
# from sklearn.tree import DecisionTreeClassifier

# Score_test = {}
# Score_train = {}


# for variance in range(20):
#     print("\nVariance",variance)
    
#     Col_train = Xtrainchallenge.std() > variance
#     Col_train = [i for i in Col_train.index if Col_train[i]==True]

#     Col_test = Xtestchallenge.std() > variance
#     Col_test = [i for i in Col_test.index if Col_test[i]==True]

#     Col = list(set(Col_train) & set(Col_test))
    
#     Xtrainchallenge = Xtrainchallenge[Col]
#     Xtestchallenge = Xtestchallenge[Col]
    
#     X_train, X_test, y_train, y_test = train_test_split(Xtrainchallenge,Ytrainchallenge,test_size = 0.1)
    
#     parameters = {
#     "criterion": ["gini", "entropy"],
#     "max_depth":[3, 5, 8, 10],
#     "min_samples_split": [2, 0.001, 0.005],
#     "min_samples_leaf": [0.001, 0.005, 0.01, 0.01, 0.05],
#     "max_features": [1., "sqrt"]
#     }

#     clf_DT = GridSearchCV(DecisionTreeClassifier(), parameters, cv=5, n_jobs=-1,verbose=1)

#     clf_DT.fit(X_train, y_train)
    
#     print("Train: ",clf_DT.score(X_train, y_train))
#     print("Test: ",clf_DT.score(X_test, y_test))
    
#     Score_test[variance] = round(clf_DT.score(X_test, y_test),2)
#     Score_train[variance] = round(clf_DT.score(X_train, y_train),2)

# %%
# Score_test

# %%
# Score_train

# %%
# from sklearn.tree import DecisionTreeClassifier

# variance = 1

# Col_train = Xtrainchallenge.std() > variance
# Col_train = [i for i in Col_train.index if Col_train[i]==True]

# Col_test = Xtestchallenge.std() > variance
# Col_test = [i for i in Col_test.index if Col_test[i]==True]

# Col = list(set(Col_train) & set(Col_test))
    
# Xtrainchallenge = Xtrainchallenge[Col]
# Xtestchallenge = Xtestchallenge[Col]
    
    
# parameters = {
#     "criterion": ["gini", "entropy"],
#     "max_depth":[3, 5, 8, 10],
#     "min_samples_split": [2, 0.001, 0.005],
#     "min_samples_leaf": [0.001, 0.005, 0.01, 0.01, 0.05],
#     "max_features": [1., "sqrt"]
# }

# clf_DT = GridSearchCV(DecisionTreeClassifier(), parameters, cv=5, n_jobs=-1,verbose=10)

# clf_DT.fit(Xtrainchallenge, Ytrainchallenge)
    
# print("Train: ",clf_DT.score(Xtrainchallenge, Ytrainchallenge))

# %%
# y_pred = clf_DT .predict(Xtestchallenge)
# np.savetxt('WADE_ArbreDecision.txt', np.transpose(y_pred),fmt='% 0d')

# %%
# variance = 9

# Col_train = Xtrainchallenge.std() > variance
# Col_train = [i for i in Col_train.index if Col_train[i]==True]

# Col_test = Xtestchallenge.std() > variance
# Col_test = [i for i in Col_test.index if Col_test[i]==True]

# Col = list(set(Col_train) & set(Col_test))

# Xtrainchallenge = Xtrainchallenge[Col]
# Xtestchallenge = Xtestchallenge[Col]

# %%
# from sklearn.ensemble import GradientBoostingClassifier

# parameters = {
#     "loss":["deviance", "exponential"],
#     "learning_rate": [0.001, 0.005, 0.01],
#     "min_samples_leaf": [0.0001, 0.005, 0.01],
#      "min_samples_split" : [2, 10],
#      "min_impurity_decrease" : [0.0, 0.001, 0.005], 
#     "max_depth":[8, 10],
#     "max_features":["sqrt", 0.5, 0.75],
#     "criterion": ["friedman_mse"],
#     "subsample":[0.5, 1],
#     "n_estimators":[400, 500],
#     }
        
# clf_GB = GridSearchCV(GradientBoostingClassifier(), parameters, cv=5, n_jobs=-1,verbose=10)

# clf_GB.fit(Xtrainchallenge, Ytrainchallenge)

# print("Train: ",clf_GB.score(Xtrainchallenge, Ytrainchallenge))
# print("\n")
# print(clf_GB.best_params_)

# %%
# y_pred = clf_GB.predict(Xtestchallenge)
# np.savetxt('WADE_GradientBoosting_Version_2.txt', np.transpose(y_pred),fmt='% 0d')

# %%
# # save the model to disk
# filename = 'modeles/clf_GB_2'
# joblib.dump(clf_GB, filename)

# # # load the model from disk
# # loaded_model = joblib.load('modeles/clf_GB_2')

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier

#pour les scores
from sklearn.metrics import f1_score
#from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import accuracy_score
#ROC Curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
variance = 9

Col_train = Xtrainchallenge.std() > variance
Col_train = [i for i in Col_train.index if Col_train[i]==True]

Col_test = Xtestchallenge.std() > variance
Col_test = [i for i in Col_test.index if Col_test[i]==True]

Col = list(set(Col_train) & set(Col_test))

Xtrainchallenge = Xtrainchallenge[Col]
Xtestchallenge = Xtestchallenge[Col]

X_train, X_test, y_train, y_test = train_test_split(Xtrainchallenge,Ytrainchallenge,test_size = 0.2)

# %%
#instantiate model and train

n_estimators = [100, 200, 300, 400, 500]
learning_rate = [0.0001, 0.001, 0.01, 0.1]
myXGBoost = XGBClassifier(learning_rate = 0.005, n_estimators=400, max_depth=8)
eval_set = [(X_test, y_test)]
eval_metric = ["auc","error","logloss"]
myXGBoost.fit(X_train, y_train, early_stopping_rounds=30, eval_metric="error", eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-error:0.23
# Will train until validation_0-error hasn't improved in 30 rounds.
# [1]	validation_0-error:0.21
# [2]	validation_0-error:0.2
# [3]	validation_0-error:0.21
# [4]	validation_0-error:0.215
# [5]	validation_0-error:0.225
# [6]	validation_0-error:0.22
# [7]	validation_0-error:0.22
# [8]	validation_0-error:0.22
# [9]	validation_0-error:0.22
# [10]	validation_0-error:0.22
# [11]	validation_0-error:0.22
# [12]	validation_0-error:0.22
# [13]	validation_0-error:0.22
# [14]	validation_0-error:0.22
# [15]	validation_0-error:0.22
# [16]	validation_0-error:0.22
# [17]	validation_0-error:0.225
# [18]	validation_0-error:0.22
# [19]	validation_0-error:0.225
# [20]	validation_0-error:0.225
# [21]	validation_0-error:0.22
# [22]	validation_0-error:0.225
# [23]	validation_0-error:0.225
# [24]	validation_0-error:0.22
# [25]	validation_0-error:0.225
# [26]	validation_0-error:0.22
# [27]	validation_0-error:0.215
# [28]	validation_0-error:0.215
# [29]	validation_0-error:0.215
# [30]	validation_0-error:0.215
# [31]	validation_0-error:0.215
# [32]	validation_0-error:0.215
# Stopping. Best iteration:
# [2]	validation_0-error:0.2
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.005, max_delta_step=0, max_depth=8,
#               min_child_weight=1, missing=None, n_estimators=400, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
# make predictions for test set
y_pred = myXGBoost.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.))
# Out:
# Accuracy: 80.00%

# %%
# from xgboost import XGBClassifier

# parameters = {
#     "eta" : [0.1, 0.3, 0.6, 1.0],
#     "gamma": [0.1, 0.5, 0.75],
#     "subsample": [0.5, 0.75, 1.0],
#     "colsample_bytree": [0.5, 0.75, 1.0],
#     "learning_rate": [0.0005, 0.001, 0.005, 0.01, 0.1],
#     "min_samples_leaf": [0.0005, 0.05],
#     "max_depth":[3, 5, 8],
#     "max_features":[[0.5, 0.75, 1.0],
#     "gamma": [0, 0.5],
#     "n_estimators":[100, 200, 400],
#     }

                
# clf_XGB = GridSearchCV(XGBClassifier(), parameters, cv=5, n_jobs=-1,verbose=10)

# clf_XGB.fit(X_train, y_train, early_stopping_rounds=20, eval_metric="error", eval_set=eval_set, verbose=True)

# print("Train: ",clf_XGB.score(X_train, y_train))
# print("Test: ",clf_XGB.score(X_test, y_test))
# print("\n")
# print(clf_XGB.best_params_)
# Out:
# Fitting 5 folds for each of 1152 candidates, totalling 5760 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:   16.4s
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:   24.8s
# [Parallel(n_jobs=-1)]: Done 173 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=-1)]: Done 213 tasks      | elapsed:   39.7s
# [Parallel(n_jobs=-1)]: Done 234 tasks      | elapsed:   45.1s
# [Parallel(n_jobs=-1)]: Done 257 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:   59.1s
# [Parallel(n_jobs=-1)]: Done 305 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 384 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 413 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 473 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 504 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 537 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 570 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 605 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 677 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 714 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 753 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 833 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 874 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 917 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 960 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 1050 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 1097 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 1144 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 1193 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 1344 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 1397 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done 1450 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done 1505 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 1560 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done 1617 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 1674 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 1733 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 1853 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 1914 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done 1977 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 2040 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 2105 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 2170 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 2237 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 2304 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 2373 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 2513 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 2584 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=-1)]: Done 2657 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 2730 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 2805 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 2880 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 2957 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done 3034 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 3113 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 3273 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done 3354 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 3437 tasks      | elapsed: 17.0min
# [Parallel(n_jobs=-1)]: Done 3520 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 3605 tasks      | elapsed: 18.5min
# [Parallel(n_jobs=-1)]: Done 3690 tasks      | elapsed: 19.1min
# [Parallel(n_jobs=-1)]: Done 3777 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 3864 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done 3953 tasks      | elapsed: 21.6min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed: 22.2min
# [Parallel(n_jobs=-1)]: Done 4133 tasks      | elapsed: 22.8min
# [Parallel(n_jobs=-1)]: Done 4224 tasks      | elapsed: 23.5min
# [Parallel(n_jobs=-1)]: Done 4317 tasks      | elapsed: 24.3min
# [Parallel(n_jobs=-1)]: Done 4410 tasks      | elapsed: 24.6min
# [Parallel(n_jobs=-1)]: Done 4505 tasks      | elapsed: 25.1min
# [Parallel(n_jobs=-1)]: Done 4600 tasks      | elapsed: 25.8min
# [Parallel(n_jobs=-1)]: Done 4697 tasks      | elapsed: 26.6min
# [Parallel(n_jobs=-1)]: Done 4794 tasks      | elapsed: 27.0min
# [Parallel(n_jobs=-1)]: Done 4893 tasks      | elapsed: 27.7min
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed: 28.6min
# [Parallel(n_jobs=-1)]: Done 5093 tasks      | elapsed: 29.4min
# [Parallel(n_jobs=-1)]: Done 5194 tasks      | elapsed: 30.2min
# [Parallel(n_jobs=-1)]: Done 5297 tasks      | elapsed: 31.1min
# [Parallel(n_jobs=-1)]: Done 5400 tasks      | elapsed: 32.2min
# [Parallel(n_jobs=-1)]: Done 5505 tasks      | elapsed: 32.8min
# [Parallel(n_jobs=-1)]: Done 5610 tasks      | elapsed: 33.6min
# [Parallel(n_jobs=-1)]: Done 5717 tasks      | elapsed: 34.6min
# [0]	validation_0-error:0.125
# Will train until validation_0-error hasn't improved in 20 rounds.
# [1]	validation_0-error:0.115
# [2]	validation_0-error:0.12
# [3]	validation_0-error:0.105
# [4]	validation_0-error:0.1
# [5]	validation_0-error:0.095
# [Parallel(n_jobs=-1)]: Done 5760 out of 5760 | elapsed: 34.9min finished
# /opt/conda/lib/python3.7/site-packages/sklearn/preprocessing/label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/lib/python3.7/site-packages/sklearn/preprocessing/label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [6]	validation_0-error:0.085
# [7]	validation_0-error:0.09
# [8]	validation_0-error:0.08
# [9]	validation_0-error:0.09
# [10]	validation_0-error:0.08
# [11]	validation_0-error:0.08
# [12]	validation_0-error:0.09
# [13]	validation_0-error:0.085
# [14]	validation_0-error:0.09
# [15]	validation_0-error:0.1
# [16]	validation_0-error:0.095
# [17]	validation_0-error:0.085
# [18]	validation_0-error:0.09
# [19]	validation_0-error:0.095
# [20]	validation_0-error:0.09
# [21]	validation_0-error:0.09
# [22]	validation_0-error:0.085
# [23]	validation_0-error:0.085
# [24]	validation_0-error:0.085
# [25]	validation_0-error:0.08
# [26]	validation_0-error:0.08
# [27]	validation_0-error:0.08
# [28]	validation_0-error:0.075
# [29]	validation_0-error:0.065
# [30]	validation_0-error:0.07
# [31]	validation_0-error:0.06
# [32]	validation_0-error:0.055
# [33]	validation_0-error:0.055
# [34]	validation_0-error:0.04
# [35]	validation_0-error:0.05
# [36]	validation_0-error:0.04
# [37]	validation_0-error:0.035
# [38]	validation_0-error:0.035
# [39]	validation_0-error:0.04
# [40]	validation_0-error:0.035
# [41]	validation_0-error:0.035
# [42]	validation_0-error:0.035
# [43]	validation_0-error:0.04
# [44]	validation_0-error:0.04
# [45]	validation_0-error:0.035
# [46]	validation_0-error:0.035
# [47]	validation_0-error:0.04
# [48]	validation_0-error:0.035
# [49]	validation_0-error:0.035
# [50]	validation_0-error:0.035
# [51]	validation_0-error:0.035
# [52]	validation_0-error:0.04
# [53]	validation_0-error:0.04
# [54]	validation_0-error:0.04
# [55]	validation_0-error:0.04
# [56]	validation_0-error:0.04
# [57]	validation_0-error:0.04
# Stopping. Best iteration:
# [37]	validation_0-error:0.035
#
# Train:  0.9925
# Test:  0.83
#
#
# {'colsample_bytree': 0.66, 'gamma': 0.5, 'learning_rate': 0.05, 'max_depth': 5, 'max_features': 0.7, 'min_samples_leaf': 0.0005, 'n_estimators': 100, 'subsample': 1.0}

# %%
y_pred_XBG = clf_XGB.predict(X_test)

# construire la courbe ROC
from sklearn import metrics
fpr, tpr, thr = metrics.roc_curve(y_test, y_pred_XBG)

# calculer l'aire sous la courbe ROC
auc = metrics.auc(fpr, tpr)

# créer une figure
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(7,7))

# afficher la courbe ROC
plt.plot(fpr, tpr, '-', lw=2, label='AUC=%.2f' % auc)

# donner un titre aux axes et au graphique
plt.xlabel('False Positive Rate', fontsize=16)
plt.ylabel('True Positive Rate', fontsize=16)
plt.title('Courbe ROC Décision Tree', fontsize=16)

# afficher la légende
plt.legend(loc="lower right", fontsize=14)

# afficher l'image
plt.show()

# %%
# # save the model to disk
# filename = 'modeles/clf_XGBOOST_1'
# joblib.dump(clf_XGB, filename)
# Out:
# ['modeles/clf_XGBOOST_1']

# %%
# y_pred_XGB = clf_XGB.predict(Xtestchallenge)
# np.savetxt('WADE_XGBoost_Version_1.txt', np.transpose(y_pred_XGB),fmt='% 0d')

# %%
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials

# %% [raw]
# Hyperopt est une bibliothèque python pour optimiser les espaces de recherche. Actuellement, il offre deux algorithmes d'optimisation : 1. Recherche aléatoire et 2. Tree of Parzen Estimators (TPE) qui est une approche bayésienne qui utilise P(x|y) au lieu de P(y|x), basée sur l'approximation de deux distributions différentes séparées par un seuil au lieu d'une pour calculer l'amélioration attendue (voir ceci). Auparavant, il s'adaptait aux processus gaussiens et aux arbres de régression, mais aujourd'hui, ils ne sont plus mis en œuvre.

# %% [raw]
# fmin() est la fonction principale d'hyperopt pour l'optimisation. Il accepte quatre arguments de base et sort le jeu de paramètres optimisé :
#
# 1. Objectif Fonction - fn
# 2. Espace de recherche - espace
# 3. Algorithme de recherche - algo
# 4. (Maximum) nombre d'évaluations - max_evals
#
# Nous pouvons également passer un objet Trials à l'argument trials qui garde la trace de tout le processus. Pour fonctionner avec des tracés, la sortie de la fonction objectif doit être un dictionnaire comprenant au moins les clés "perte" et "état" qui contiennent respectivement le résultat et l'état d'optimisation. Les valeurs intermédiaires pourraient être extraites comme suit :
#
# 1. trials.trials - une liste de dictionnaires contient toutes les informations pertinentes
# 2. trials.results - une liste de dictionnaires collectant les sorties des fonctions
# 3. trials.losses() - une liste des pertes (flottant pour chaque essai'ok')
# 4. trials.statuses() - une liste de chaînes de statuts
# 5. trials.vals - un dictionnaire des paramètres échantillonnés

# %%
def score(params):
    num_round = int(params['n_estimators'])
    del params['n_estimators']
    dtrain = xgboost.DMatrix(Xtrainchallenge, label=y_train)
    dvalid = xgboost.DMatrix(Xtestchallenge, label=y_val)
    watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
    gbm_model = xgboost.train(params, 
                              dtrain, 
                              num_round,
                              evals=watchlist,
                              verbose_eval=False)
    predictions = gbm_model.predict(dvalid, ntree_limit=gbm_model.best_iteration)
    print(gini_normalized(y_val, np.array(predictions)))
    loss = 1 - gini_normalized(y_val, np.array(predictions))
    return {'loss': loss, 'status': STATUS_OK}
 
 
def optimize(evals, cores, trials, optimizer=tpe.suggest, random_state=0):
    space = {
        'n_estimators': hp.quniform('n_estimators', 200, 600, 1),
        'eta': hp.quniform('eta', 0.025, 0.25, 0.025), # A problem with max_depth casted to float instead of int with the hp.quniform method.
        'max_depth':  hp.choice('max_depth', np.arange(1, 14, dtype=int)),
        'min_child_weight': hp.quniform('min_child_weight', 1, 10, 1),
        'subsample': hp.quniform('subsample', 0.7, 1, 0.05),
        'gamma': hp.quniform('gamma', 0.5, 1, 0.05),
        'colsample_bytree': hp.quniform('colsample_bytree', 0.7, 1, 0.05),
        'alpha' :  hp.quniform('alpha', 0, 10, 1),
        'lambda': hp.quniform('lambda', 1, 2, 0.1),
        'nthread': cores,
        'objective': 'binary:logistic',
        'booster': 'gbtree',
        'seed': random_state
    }
    best = fmin(score, space, algo=tpe.suggest, max_evals=evals, trials = trials)
    return best
    

trials = Trials()
cores = 32
n= 1000
start = time.time()
best_param = optimize(evals = n,
                      optimizer=tpe.suggest,
                      cores = cores,
                      trials = trials)
print("------------------------------------")
print("The best hyperparameters are: ", "\n")
print(best_param)
end = time.time()
print('Time elapsed to optimize {0} executions: {1}'.format(n,end - start))

# %% [markdown]
# ## Conclusion:

# %% [raw]
# Avec un arbre de décision pour une variance de 1, on obtient un score de 73.8%
# Avec un Gradient Boosting pour une variance de 9, on obtient un score de 77.4%
